642965, -0.04020396, -0.007937934, -0.043468572, -0.019475888, 0.04682263, 0.023992684, 0.029560419, -0.039443705, -0.025915677, -0.009564651, 0.0028509481, -0.031707015, 0.028129354, -0.020616267, 0.027682146, 0.02437281, 0.0030046757, 0.05527485, -0.011616216, 0.047001515, -0.03269087, -0.041076012, 0.034680944, 0.038907055, -0.05853947, 0.047180396, -0.0056711505, -0.029403895, 0.013505667, -0.010296954, 0.0099559575, -0.024439892, 0.010386395, 0.014679587, 0.009223656, -0.014567786, 0.017899482, 0.059031397, -0.018100725, 0.010721801, 0.0044860505, 0.0019760984, 0.008536074, -0.041076012, -0.004282012, 0.03445734, 0.009374588, -0.012219946, -0.00949198, -0.04214931, 0.0116050355, 0.004684499, 0.032109503, 0.0011452705, 0.04156794, -0.004880152, 0.0049556186, 0.009195705, -0.0022737707, 0.055453736, 0.01786594, -0.00081964757, 0.02432809, 0.011213729, 0.0036447414, 0.026251083, -0.021577764, -0.01007335, -0.039488427, -0.002760109, 0.011526775, -0.0017818426, 0.013259703, 0.03913066, -0.041053653, -0.0039885323, 0.032310747, 0.030454833, 0.023232432, -0.021566583, 0.00036894623, -0.02130944, 0.028979048, -0.028174074, -0.017060967, -0.0052463035, -0.03503871, 0.006149104, 0.033965413, -0.025379028, -0.009978319, -0.013852254, 0.02549083, -0.04624126, 0.01898396, -0.023031188, -0.048790343, -0.0177765, -0.046464864, 0.0064397887, 0.030991483, -0.016837364, -0.023478396, 0.012901938, 0.002338057, 0.017608797, 0.017429914, 0.06600783, -0 ...

# %%
with open("koso-dogfood-export-2025-7-5-12-2.json") as new: 
    embedding = json.load(new)

# %%
tasks = embedding['graph']

# %%
tasks
# Out:
# {'5da056ad-bc67-42be-9488-e5e2eb93f71c': {'id': '5da056ad-bc67-42be-9488-e5e2eb93f71c',
#   'num': '470',
#   'name': 'Update README with once a day / after every pull instructions',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/748',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'c7ac6432-16f6-45a0-bf8d-11701c3c312f': {'id': 'c7ac6432-16f6-45a0-bf8d-11701c3c312f',
#   'num': '203',
#   'name': 'Configure CI',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1727494670266,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'ZR-1iPe6SWaYYEFbEtKnrg': {'id': 'ZR-1iPe6SWaYYEFbEtKnrg',
#   'num': '1128',
#   'name': 'Update dependency svelte to v4.2.19 [SECURITY] - autoclosed',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1753222985807,
#   'url': 'https://github.com/kosolabs/cipherly/pull/56',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '74b0c122-e13b-4718-89d6-7b34c9113ede': {'id': '74b0c122-e13b-4718-89d6-7b34c9113ede',
#   'num': '1008',
#   'name': 'Add support for archiving tasks',
#   'desc': '- Remove the feature for showing / hiding done tasks\n- Replace with ability to show / hide archived tasks\n- Managed tasks should be archiveable as well',
#   'children': ['c86c5cd4-8955-4fd7-9ccd-09387479387a'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'In Progress',
#   'statusTime': 1749668508413,
#   'url': None,
#   'kind': None,
#   'estimate': 3,
#   'deadline': None,
#   'archived': True},
#  'P526aJThQA2RNN9oPof7Sw': {'id': 'P526aJThQA2RNN9oPof7Sw',
#   'num': '1073',
#   'name': 'Fixup seats verbiage',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1750979008608,
#   'url': 'https://github.com/kosolabs/koso/pull/1215',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'doO8ZK7iSEmduTNDKsn-qA': {'id': 'doO8ZK7iSEmduTNDKsn-qA',
#   'num': '1116',
#   'name': 'Add more logging when processing anthropic requests',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1752597240345,
#   'url': 'https://github.com/kosolabs/koso/pull/1254',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'S6QEkvq5Q-ifbdzHOsgp9w': {'id': 'S6QEkvq5Q-ifbdzHOsgp9w',
#   'num': '1051',
#   'name': 'Update dependabot.yml',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1750166937857,
#   'url': 'https://github.com/kosolabs/koso/pull/1198',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'be0f71db-ef88-499c-af80-63c2914a6d01': {'id': 'be0f71db-ef88-499c-af80-63c2914a6d01',
#   'num': '737',
#   'name': 'Refactor LinkPanel and TaskStatus to take Task instead of Node',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744150582793,
#   'url': 'https://github.com/kosolabs/koso/pull/975',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'b3c15ca9-9b86-489c-94a0-da2156ac80ee': {'id': 'b3c15ca9-9b86-489c-94a0-da2156ac80ee',
#   'num': '830',
#   'name': 'Open the doors',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1746837801481,
#   'url': 'https://github.com/kosolabs/koso/pull/1053',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '799abfcd-f39a-4440-833e-7a218d7cd120': {'id': '799abfcd-f39a-4440-833e-7a218d7cd120',
#   'num': '17',
#   'name': 'Navbar Improvements',
#   'desc': None,
#   'children': ['423a28b8-74ad-4807-80b2-d7dc9ac7ad31',
#    '9b86a483-68e7-4ba8-80c4-9a137d6287a0',
#    'b488ae9e-60dc-48fc-93e1-50e92583f29f'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'c4830a3c-3909-4807-a6a8-fb46753ec3e0': {'id': 'c4830a3c-3909-4807-a6a8-fb46753ec3e0',
#   'num': '872',
#   'name': 'Suppress noisy chrome workspace logs',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747414026847,
#   'url': 'https://github.com/kosolabs/koso/pull/1075',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '23bb1e72-127b-47e4-9822-59f5731df7b4': {'id': '23bb1e72-127b-47e4-9822-59f5731df7b4',
#   'num': '957',
#   'name': 'Plugin to import review of GitHub PRs as a koso task that resolves when the PR is reviewed',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '17912f5c-78e6-4cc2-98d4-129c7fafd15f': {'id': '17912f5c-78e6-4cc2-98d4-129c7fafd15f',
#   'num': '612',
#   'name': 'Disable Delete action in inbox',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1742267625224,
#   'url': 'https://github.com/kosolabs/koso/pull/884',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'f4f98180-d216-4889-aa4c-ba1c4bf6802d': {'id': 'f4f98180-d216-4889-aa4c-ba1c4bf6802d',
#   'num': '783',
#   'name': 'Bump mode-watcher to 1.0.0',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744847053288,
#   'url': 'https://github.com/kosolabs/koso/pull/1014',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'f67714fc-8763-4af7-8887-7b0006802295': {'id': 'f67714fc-8763-4af7-8887-7b0006802295',
#   'num': '229',
#   'name': 'Move telegram notifications out of deploy.sh into the github action using appleboy/telegram-action',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'Leonhard.Kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1729794193772,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '80d3014e-607e-4379-8a37-6c77e44c405b': {'id': '80d3014e-607e-4379-8a37-6c77e44c405b',
#   'num': '223',
#   'name': 'Cmd+Shift+Option+Enter should create a new child in previous task',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1729800663995,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '2e7aa496-78d1-4df5-8fcd-31de97ae2a78': {'id': '2e7aa496-78d1-4df5-8fcd-31de97ae2a78',
#   'num': '852',
#   'name': 'Markdown editor should wrap text',
#   'desc': None,
#   'children': ['36cfbdb5-c971-452a-899c-3038a02e17c0'],
#   'assignee': None,
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'ada31236-ca88-4cdf-8c48-64f7d8f5bc2b': {'id': 'ada31236-ca88-4cdf-8c48-64f7d8f5bc2b',
#   'num': '712',
#   'name': 'Improve socket shutdown handling',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1743712638361,
#   'url': 'https://github.com/kosolabs/koso/pull/956',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '7e353788-7924-425f-8d61-2268a0413ec4': {'id': '7e353788-7924-425f-8d61-2268a0413ec4',
#   'num': '573',
#   'name': 'Try setting the exact install version',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1741388927650,
#   'url': 'https://github.com/kosolabs/koso/pull/850',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'fbadb5ff-f176-4b62-bd8f-1a051b7a1e1a': {'id': 'fbadb5ff-f176-4b62-bd8f-1a051b7a1e1a',
#   'num': '755',
#   'name': 'Fix dark mode for the editor',
#   'desc': None,
#   'children': ['82d546d3-1d0e-4509-a603-28951df268ff'],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'f52852ce-b556-47ab-8e24-0f3a5dc61360': {'id': 'f52852ce-b556-47ab-8e24-0f3a5dc61360',
#   'num': '532',
#   'name': 'Fix several lint warnings',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740697853714,
#   'url': 'https://github.com/kosolabs/koso/pull/810',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '62666e73-36bb-498c-bcbb-59d151bc4fc8': {'id': '62666e73-36bb-498c-bcbb-59d151bc4fc8',
#   'num': '912',
#   'name': 'Create a test that ensures various widths of browsers have no scrollbars',
#   'desc': "If there is any horizontal overflow, a horizontal scrollbar will appear. If this happens, by even a single pixel, scrolling on mobile becomes very janky. Usually, horizontal overflow is introduced unintentionally by adding some HTML element. We would like to have a test that simply loads various pages and detects the presence of a horizontal scrollbar.\n\nIt is possible to check whether or not the horizontal scrollbar exists by comparing the width of the screen to the width of the document's body. If the screen width is smaller than the document, then there will be a horizontal scrollbar.\n\nYou can check the screen width using this Javascript:\n\n```javascript\ndocument.body.clientWidth\n```\n\nAnd you can check the document's width using this Javascript:\n\n```javascript\ndocument.body.scrollWidth\n```\n\nBasically, the test needs to fail if `scrollWidth > clientWidth`. In playwright, this code needs to be evaluated in the context of the browser. This can be achieved using `page.evaluate` like this:\n\n```javascript\npage.evaluate(() => {\n  return document.body.clientWidth;\n});\n```\n\nTo complete this task, do the following:\n\n1. Write a function `hasHorizontalScrollbar()` that returns true if we detect that `document.body.scrollWidth > document.body.clientWidth`.\n\n2. Use this function to write tests that check for a horizontal scrollbar on the planning page, the inbox page, and the projects page.\n\nTo test that the function is working, introduce a horizontal scrollbar. Kyle and I first ran in to this problem when we added the crown badge. We fixed it in this PR: https://github.com/kosolabs/koso/pull/1103\n\nYou can verify that the test fails by removing the `overflow-hidden` from the navbar, which will reintroduce the horizontal scrollbar bug.",
#   'children': ['aEZf0vNJRs6XRmBcjS26uw',
#    '0y0xeaEhQ-W7F4p6nlroew',
#    'sgIJeEa3QDiXFxXhC3D13w'],
#   'assignee': 'sachie@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'In Progress',
#   'statusTime': 1750712169021,
#   'url': None,
#   'kind': None,
#   'estimate': 2,
#   'deadline': None,
#   'archived': None},
#  '5e6bffc9-b964-4cc0-8dba-af32bac279b6': {'id': '5e6bffc9-b964-4cc0-8dba-af32bac279b6',
#   'num': '74',
#   'name': 'Nodes should only expand after a delay when dragging',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '4071b81a-b9f2-4802-b288-09112f44d195': {'id': '4071b81a-b9f2-4802-b288-09112f44d195',
#   'num': '564',
#   'name': 'Handle juggled tasks in toggle status',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1741055723419,
#   'url': 'https://github.com/kosolabs/koso/pull/841',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'fc1c98d5-dbd0-4303-9074-b169b231d282': {'id': 'fc1c98d5-dbd0-4303-9074-b169b231d282',
#   'num': '895',
#   'name': 'Fix task deep links',
#   'desc': "Clicking a link from a notification should navigate the user to the task. \nBut often, if the user hasn't visited the project in the interim, the task won't be present yet in their local copy. As a result, no task will end up selected.",
#   'children': ['c0188fa6-0cd7-4847-92f8-6cefaafac398',
#    'f3511888-3493-498b-9e2d-8da64d5edc4b'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'In Progress',
#   'statusTime': 1747692684452,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '22eab22d-68f6-4936-a1cb-77916323c21f': {'id': '22eab22d-68f6-4936-a1cb-77916323c21f',
#   'num': '556',
#   'name': 'Simplify render delegation by using useRef callback instead of element box',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740975085924,
#   'url': 'https://github.com/kosolabs/koso/pull/833',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '5021555b-1b8f-4962-817c-8a2c9b780db1': {'id': '5021555b-1b8f-4962-817c-8a2c9b780db1',
#   'num': '436',
#   'name': 'Adopt tailwind-variants in Kosui',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/718',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'ee7f3539-8e7f-4854-ad29-d5b0fe313f43': {'id': 'ee7f3539-8e7f-4854-ad29-d5b0fe313f43',
#   'num': '561',
#   'name': 'Refactor status, kind and progress handling',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1741054393117,
#   'url': 'https://github.com/kosolabs/koso/pull/838',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '2b9f85cd-9aee-4fb4-b556-981f5f187ab1': {'id': '2b9f85cd-9aee-4fb4-b556-981f5f187ab1',
#   'num': '858',
#   'name': 'Display badges for premium members',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747347095938,
#   'url': 'https://github.com/kosolabs/koso/pull/1064',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '020f9225-e122-4550-9cb9-5705306356fe': {'id': '020f9225-e122-4550-9cb9-5705306356fe',
#   'num': '250',
#   'name': 'project-share-modal.svelte',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1730490031277,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '2b1a04e1-fe97-400b-b5a1-dfa95eff8499': {'id': '2b1a04e1-fe97-400b-b5a1-dfa95eff8499',
#   'num': '877',
#   'name': 'Downgrade to rust 1.86',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747435786927,
#   'url': 'https://github.com/kosolabs/koso/pull/1080',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '68d430da-ac8d-4129-bacc-bc785ed50324': {'id': '68d430da-ac8d-4129-bacc-bc785ed50324',
#   'num': '770',
#   'name': 'Break circular import deps',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744501908964,
#   'url': 'https://github.com/kosolabs/koso/pull/1001',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'b547372d-a894-4e42-9c0b-6b696258707d': {'id': 'b547372d-a894-4e42-9c0b-6b696258707d',
#   'num': '967',
#   'name': 'Uses enum style constants for ActionIDs instead of relying on types',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1748638341399,
#   'url': 'https://github.com/kosolabs/koso/pull/1141',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'e4d73ce7-2ba7-4c96-9ba5-ddbf73bdd7b6': {'id': 'e4d73ce7-2ba7-4c96-9ba5-ddbf73bdd7b6',
#   'num': '807',
#   'name': 'Bump the npm-deps group across 1 directory with 13 updates',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1746122968319,
#   'url': 'https://github.com/kosolabs/koso/pull/1038',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'cf4b9e4a-664a-4fb6-b280-1599b2b40a11': {'id': 'cf4b9e4a-664a-4fb6-b280-1599b2b40a11',
#   'num': '602',
#   'name': 'Handle selection when tasks disappear',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1742052641928,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '99b6ad1d-f574-46d4-bb8a-c6abfa26fb7f': {'id': '99b6ad1d-f574-46d4-bb8a-c6abfa26fb7f',
#   'num': '1013',
#   'name': 'Make action item tooltip clearer',
#   'desc': '- Header indicates the action to be performed \n- Body explains the reason why the action is important',
#   'children': ['f72b4c63-4ac8-4cc1-affb-f8fb24e74bf2'],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1749709676466,
#   'url': None,
#   'kind': 'Task',
#   'estimate': 3,
#   'deadline': None,
#   'archived': True},
#  'xNzZ5Zq8TWiTIpsM8PYAbQ': {'id': 'xNzZ5Zq8TWiTIpsM8PYAbQ',
#   'num': '1125',
#   'name': 'aAdd note about remote server',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1753208079714,
#   'url': 'https://github.com/kosolabs/koso/pull/1262',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '5f2cf3a7-8e85-499c-9a29-986297b2bd21': {'id': '5f2cf3a7-8e85-499c-9a29-986297b2bd21',
#   'num': '273',
#   'name': 'Add commands to cycle between the nodes of a task',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1732043913048,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'Ra7Fd4NASmSAIEytXxu5HQ': {'id': 'Ra7Fd4NASmSAIEytXxu5HQ',
#   'num': '1048',
#   'name': 'Experiment fixing Svelte bug',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1750111640991,
#   'url': 'https://github.com/kosolabs/koso/pull/1195',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '872fdc06-0cac-47be-8fc4-dc9f1d5bc04e': {'id': '872fdc06-0cac-47be-8fc4-dc9f1d5bc04e',
#   'num': '12',
#   'name': 'Usability',
#   'desc': None,
#   'children': ['e382263f-a270-402f-8d53-6a5ffbdd635a',
#    '5f2cf3a7-8e85-499c-9a29-986297b2bd21',
#    '26b86072-6047-4668-a0f3-5bdc869fb2a2',
#    '1b2a1da2-a6a1-465a-8745-09737ac89b8c',
#    '39a5201a-a319-4347-8582-8e2a2a8c7f8e',
#    '552dc037-69d2-4e2e-90e3-b92b551ff70e',
#    '93fc6e1a-531a-42c1-953f-da63d93afe80',
#    '57dfc333-f7fa-4fdc-af76-6ff24d1623b7',
#    'aec70557-0657-4f64-b39e-1a23d593818f',
#    '93e8cc0b-946c-44c3-bc7c-ac1fdd22b4c1',
#    '5e6bffc9-b964-4cc0-8dba-af32bac279b6',
#    '4e2df9c8-c0d4-42d3-b3e9-3bfb88736fa3',
#    'f71d68bd-58a0-4301-8edc-bf239ca0ccaa',
#    '131e717c-bfe5-4909-a645-68b313792fd9',
#    '3c044062-9f9e-447b-a068-924e5e90b467',
#    'e2861e11-8587-4ddb-ad59-422dd9cf4b4a',
#    '4c4c0ac8-c5a2-487e-96da-19a9470bfa31',
#    '83ebf1e5-eefa-4fc8-ba42-6d1b54785bbd',
#    'bb67c52c-bb59-49a5-b366-d8796e12f1e6',
#    '1d98085b-fd47-421e-ab07-46f5e455a181',
#    '19a16c16-e590-4faf-ad84-6c5f5b39631c',

#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '950f19c7-f25a-4bf3-b813-d3991f31ac9d': {'id': '950f19c7-f25a-4bf3-b813-d3991f31ac9d',
#   'num': '1001',
#   'name': 'Add support for floating tasks',
#   'desc': 'When a task a rollup is assigned to a user, all of its unassigned children are shown in the user\'s inbox. Sometimes, we want to mark a task as ready for work, but leave it unassigned so that the next available engineer can work on it.\n\nOne thought is to make it so that when a task is ready for work, it should be assigned to "the team", or to some kind of bot, that would raise the task to the next available engineer, perhaps based on priority.',
#   'children': ['51eca712-5fbd-4f24-993e-d1b4afb3356a'],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1749844249411,
#   'url': None,
#   'kind': 'Task',
#   'estimate': 3,
#   'deadline': None,
#   'archived': True},
#  'XBiBI403S6SIQFf1VlDcsQ': {'id': 'XBiBI403S6SIQFf1VlDcsQ',
#   'num': '1206',
#   'name': 'Try fixing down cast',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1753896212745,
#   'url': 'https://github.com/kosolabs/koso/pull/1277',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '56c06f7f-20d3-45b9-b1b7-6b0413d8d01c': {'id': '56c06f7f-20d3-45b9-b1b7-6b0413d8d01c',
#   'num': '163',
#   'name': 'Add integration tests for collaboration',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1727822448948,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'ca9d525d-b86d-43c4-aa3c-360a3cc3ae23': {'id': 'ca9d525d-b86d-43c4-aa3c-360a3cc3ae23',
#   'num': '891',
#   'name': 'koso-853: Add a `rich` flag to Tooltip component for styling Rich Tooltips',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747689281864,
#   'url': 'https://github.com/kosolabs/koso/pull/1094',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'c6fea87c-9556-41b1-833c-9da2d9418e33': {'id': 'c6fea87c-9556-41b1-833c-9da2d9418e33',
#   'num': '145',
#   'name': 'Implement client side warnings when schema is off',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '6a11b95f-0e89-4c9e-8fcf-9594621aa2e3': {'id': '6a11b95f-0e89-4c9e-8fcf-9594621aa2e3',
#   'num': '698',
#   'name': 'Add support for GitHub reference links',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1743547188681,
#   'url': 'https://github.com/kosolabs/koso/pull/944',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'a3827817-a13a-41f8-b191-bbee2bd79636': {'id': 'a3827817-a13a-41f8-b191-bbee2bd79636',
#   'num': '896',
#   'name': 'Add action to copy task permalink to the clipboard',
#   'desc': None,
#   'children': ['4a865f94-4366-4c12-8fa2-6c5a4733c1f4'],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'In Progress',
#   'statusTime': 1747870541572,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'b8903fef-9695-431a-bf15-44f577643ad9': {'id': 'b8903fef-9695-431a-bf15-44f577643ad9',
#   'num': '534',
#   'name': 'Promote Chips to Kosui',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740708552517,
#   'url': 'https://github.com/kosolabs/koso/pull/811',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '0f97e324-02c5-4e39-88e8-01fbfb989899': {'id': '0f97e324-02c5-4e39-88e8-01fbfb989899',
#   'num': '420',
#   'name': 'Bump openssl from 0.10.68 to 0.10.70 in the cargo group across 1 directory',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/702',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '0a9659ae-91be-4de5-b69e-58182133a0cf': {'id': '0a9659ae-91be-4de5-b69e-58182133a0cf',
#   'num': '978',
#   'name': 'Add a category field to help organize the command palette',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1748891869262,
#   'url': 'https://github.com/kosolabs/koso/pull/1150',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '84173e80-db91-4d5b-8e79-b9ff9af5d5a7': {'id': '84173e80-db91-4d5b-8e79-b9ff9af5d5a7',
#   'num': '1000',
#   'name': 'Archive',
#   'desc': None,
#   'children': ['36db2f04-28e6-4f8e-b06a-456196246e24',
#    '5c199915-786e-4ec1-996e-c18d2cd02cdf',
#    '06aa22f4-35f5-4551-8e39-42c044caad13',
#    '9db0d6f7-3d1d-4f11-a812-d5f5e78f9742',
#    '465528b0-c6bb-4697-b7dc-2e42604d0e50',
#    '33807d79-87cc-4132-9586-6179077840ff',
#    'ab9d04d7-d2c7-4581-9622-d5e519c0f84d'],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'ea6146d6-0816-46b1-bd16-0035b2ed467a': {'id': 'ea6146d6-0816-46b1-bd16-0035b2ed467a',
#   'num': '228',
#   'name': 'Update secondary colors to provide a nice contrast',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1729720927775,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '07ed5695-87c1-4bb4-96ef-cde12373d02c': {'id': '07ed5695-87c1-4bb4-96ef-cde12373d02c',
#   'num': '796',
#   'name': 'Update all dependencies',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1745249017238,
#   'url': 'https://github.com/kosolabs/koso/pull/1027',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'ce738db1-b5e0-430a-99f2-fa39c59611a0': {'id': 'ce738db1-b5e0-430a-99f2-fa39c59611a0',
#   'num': '763',
#   'name': 'Use project context in task detail page',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744397072955,
#   'url': 'https://github.com/kosolabs/koso/pull/994',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'c58448c3-69b1-4ee0-af5e-0bfdfc961496': {'id': 'c58448c3-69b1-4ee0-af5e-0bfdfc961496',
#   'num': '911',
#   'name': 'koso-910: Fix premium crown causing horizontal scroll',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747770276226,
#   'url': 'https://github.com/kosolabs/koso/pull/1103',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'cb0d11f0-f17c-4548-9b5d-30ab7603e1cc': {'id': 'cb0d11f0-f17c-4548-9b5d-30ab7603e1cc',
#   'num': '702',
#   'name': 'stylable markdown',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1743557392024,
#   'url': 'https://github.com/kosolabs/koso/pull/947',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'kT_heQ6-RmSub0IqdRWLCA': {'id': 'kT_heQ6-RmSub0IqdRWLCA',
#   'num': '1237',
#   'name': 'Create Teams app registration documentation',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '2a6bbe3b-ee4a-40cb-ba4a-f96023ad6448': {'id': '2a6bbe3b-ee4a-40cb-ba4a-f96023ad6448',
#   'num': '454',
#   'name': 'Bump the docker-deps group with 2 updates',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/732',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'bc93ab1f-170e-49eb-8006-bf683800655a': {'id': 'bc93ab1f-170e-49eb-8006-bf683800655a',
#   'num': '170',
#   'name': 'circular-progress-status',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'c4833956-4f90-49e2-a77c-2d9054fc867b': {'id': 'c4833956-4f90-49e2-a77c-2d9054fc867b',
#   'num': '882',
#   'name': 'Run clippy over tests',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747441843626,
#   'url': 'https://github.com/kosolabs/koso/pull/1085',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '9440c7fa-0bd6-4312-baa0-21040a4d2e02': {'id': '9440c7fa-0bd6-4312-baa0-21040a4d2e02',
#   'num': '730',
#   'name': 'Add support for mermaid diagrams',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1746554720002,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '3e3d349d-9256-4ff3-a2f7-bda50ee68388': {'id': '3e3d349d-9256-4ff3-a2f7-bda50ee68388',
#   'num': '654',
#   'name': 'Refactor Kosui autocomplete component to use a Svelte context',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1742937181457,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '37d4df42-eb68-49b0-a253-b302146c2099': {'id': '37d4df42-eb68-49b0-a253-b302146c2099',
#   'num': '557',
#   'name': 'Update all dependencies',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1741017768626,
#   'url': 'https://github.com/kosolabs/koso/pull/834',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '9f02d675-2a24-4502-bb61-287e60282767': {'id': '9f02d675-2a24-4502-bb61-287e60282767',
#   'num': '542',
#   'name': 'Add uncontrolled flag to Menu to disable close onSelect',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740796968058,
#   'url': 'https://github.com/kosolabs/koso/pull/819',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '9b86a483-68e7-4ba8-80c4-9a137d6287a0': {'id': '9b86a483-68e7-4ba8-80c4-9a137d6287a0',
#   'num': '7',
#   'name': 'Make Navbar available on all pages',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '9db0d6f7-3d1d-4f11-a812-d5f5e78f9742': {'id': '9db0d6f7-3d1d-4f11-a812-d5f5e78f9742',
#   'num': '168',
#   'name': 'Svelte 5: Migration',
#   'desc': None,
#   'children': ['a81af57b-7481-4d36-8143-a5f7fd035712',
#    '1c5a91ac-5d33-4047-9e50-3cb7914cfca3',
#    'ded2421d-2507-4db7-8fa7-bd1a875b24e9',
#    'aad1d3ef-c6c3-4100-95b5-5973f7b0abc5',
#    '17eebd97-1408-4ef8-a09f-5dd6274b6a70',
#    'bc93ab1f-170e-49eb-8006-bf683800655a',
#    '5e0da712-b0f0-4515-8ae0-e9da8dd04004',
#    '86693605-0eb8-4f63-b415-bf98daff8dd9',
#    'cc09a053-7bcb-46a0-9d69-636e8ecc7772',
#    'e012cb84-63b0-4b54-bb28-a0525342075a',
#    '50a2cc66-e195-4916-b293-d6a857ef93cd',
#    '805b5ed5-32b3-42b0-b9f2-698e4c896c8b',
#    'd0a88c81-6ad9-44ff-9e2b-449de51a6af8',
#    '2e97cbac-b5b4-4dc7-9dfd-41646753a8e8',
#    '493925eb-ee90-4402-9826-9ec51d159fe9',
#    '99362b6c-f444-4379-b98b-a4a42fce73f5',
#    'bea4e276-4dd5-4f97-9c87-7300e25811c7',
#    'fb51dd9c-27f9-49f9-9d76-22cfdd24f540',
#    '03cdace8-632f-4d31-bf67-88b5b703d985',
#    '020f9225-e122-4550-9cb9-5705306356fe'],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': 1749415743611,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '04062d43-129e-4a7d-9825-e3b229d75df6': {'id': '04062d43-129e-4a7d-9825-e3b229d75df6',
#   'num': '551',
#   'name': 'Implement render delegated version of Kosui menu',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740889279251,
#   'url': 'https://github.com/kosolabs/koso/pull/828',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '43f47b02-c394-4e87-a337-9bc9c0f4f8ea': {'id': '43f47b02-c394-4e87-a337-9bc9c0f4f8ea',
#   'num': '97',
#   'name': 'Add our first UI interaction test',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '179193c3-3967-407a-b75e-51053846feeb': {'id': '179193c3-3967-407a-b75e-51053846feeb',
#   'num': '823',
#   'name': 'Add experimental support for mermaid diagrams',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1746485043931,
#   'url': 'https://github.com/kosolabs/koso/pull/1051',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '1d624f06-59b4-46ea-9423-afc08160373c': {'id': '1d624f06-59b4-46ea-9423-afc08160373c',
#   'num': '110',
#   'name': 'Write an integration test',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'e69b6fcd-8d70-463f-b58d-66c1ac382454': {'id': 'e69b6fcd-8d70-463f-b58d-66c1ac382454',
#   'num': '142',
#   'name': 'Fix "Take me home" dialog escape',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'Csgu2P8RQUSTF72CbiHDWA': {'id': 'Csgu2P8RQUSTF72CbiHDWA',
#   'num': '1250',
#   'name': 'Try a different environment variable name for publishing',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1754088082348,
#   'url': 'https://github.com/kosolabs/kosui/pull/11',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '2c88e765-2cb9-4a18-b8f2-bb89e000b0be': {'id': '2c88e765-2cb9-4a18-b8f2-bb89e000b0be',
#   'num': '85',
#   'name': 'By default, tasks that have children should show progress for status',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'kyXMNEBxShWg8q1oiCHZgw': {'id': 'kyXMNEBxShWg8q1oiCHZgw',
#   'num': '1044',
#   'name': 'Correct multi-ecosystem-group pattern',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1750095084742,
#   'url': 'https://github.com/kosolabs/koso/pull/1191',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '1050643b-2355-4eba-bc18-38219760918b': {'id': '1050643b-2355-4eba-bc18-38219760918b',
#   'num': '772',
#   'name': 'Update pnpm to v10.8.1',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744645887704,
#   'url': 'https://github.com/kosolabs/koso/pull/1003',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '4e8c897d-e3cf-4409-a9fb-7e33b435f67a': {'id': '4e8c897d-e3cf-4409-a9fb-7e33b435f67a',
#   'num': '762',
#   'name': 'Add type for awareness update',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744394053667,
#   'url': 'https://github.com/kosolabs/koso/pull/993',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'xLpT1hwnTyGTa-Kfnjh6cw': {'id': 'xLpT1hwnTyGTa-Kfnjh6cw',
#   'num': '1061',
#   'name': 'Fix static content links to work for unauthenticated users',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1750410851348,
#   'url': 'https://github.com/kosolabs/koso/pull/1207',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '76cd6bee-b952-489e-a93c-09f6c29268b3': {'id': '76cd6bee-b952-489e-a93c-09f6c29268b3',
#   'num': '1003',
#   'name': 'Add a cool UI effect when a user earns points',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Ready',
#   'statusTime': 1751159307157,
#   'url': None,
#   'kind': 'Task',
#   'estimate': 3,
#   'deadline': None,
#   'archived': None},
#  'VvuxPKbsRaihInfM4aQa_w': {'id': 'VvuxPKbsRaihInfM4aQa_w',
#   'num': '1234',
#   'name': 'Add Teams integration tests',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'e4be31ff-b56e-4b77-8423-d0d848dd77f4': {'id': 'e4be31ff-b56e-4b77-8423-d0d848dd77f4',
#   'num': '583',
#   'name': 'Delete shadcn-svelte dropdown-menu component',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1741742056420,
#   'url': 'https://github.com/kosolabs/koso/pull/860',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'dae27b7f-8a3e-46f1-b26c-3397f616175a': {'id': 'dae27b7f-8a3e-46f1-b26c-3397f616175a',
#   'num': '959',
#   'name': 'Add task size estimate field that defaults to days in Fibonacci',
#   'desc': None,
#   'children': ['34e23128-e0e3-4045-8718-6f700d9d29aa'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'In Progress',
#   'statusTime': 1748626111439,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'ac2de6d4-1b19-4f55-81f4-b623125c7bb7': {'id': 'ac2de6d4-1b19-4f55-81f4-b623125c7bb7',
#   'num': '740',
#   'name': 'Stop using node in organizeTasks',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744152092224,
#   'url': 'https://github.com/kosolabs/koso/pull/978',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '02a0fd41-7e83-4aec-b5c5-8d8b533219ac': {'id': '02a0fd41-7e83-4aec-b5c5-8d8b533219ac',
#   'num': '844',
#   'name': 'Rename Row -> DagRow to match TaskTable / TaskRow',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1746837008894,
#   'url': 'https://github.com/kosolabs/koso/pull/1060',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'd0a88c81-6ad9-44ff-9e2b-449de51a6af8': {'id': 'd0a88c81-6ad9-44ff-9e2b-449de51a6af8',
#   'num': '198',
#   'name': 'dag-table/table',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1727870207181,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '0a31a1bd-8de9-4384-86d8-828911325717': {'id': '0a31a1bd-8de9-4384-86d8-828911325717',
#   'num': '624',
#   'name': 'Use the success toast variant',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1742408952699,
#   'url': 'https://github.com/kosolabs/koso/pull/896',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '2ad876ae-81d8-4eb8-a0e9-f6c32982032f': {'id': '2ad876ae-81d8-4eb8-a0e9-f6c32982032f',
#   'num': '201',
#   'name': 'Remove old images from github containers',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1727494668556,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'fc99e208-3ba2-4b56-9aa3-53a0e9ba5afc': {'id': 'fc99e208-3ba2-4b56-9aa3-53a0e9ba5afc',
#   'num': '760',
#   'name': 'Split planning context tests from koso tests',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744390732241,
#   'url': 'https://github.com/kosolabs/koso/pull/991',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'e2861e11-8587-4ddb-ad59-422dd9cf4b4a': {'id': 'e2861e11-8587-4ddb-ad59-422dd9cf4b4a',
#   'num': '65',
#   'name': 'Creating a new project errors on first load with "Error: Task ID <ID> not found in yGraph"',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'c1d2ca4d-2950-4035-981a-3867e51233f3': {'id': 'c1d2ca4d-2950-4035-981a-3867e51233f3',
#   'num': '465',
#   'name': 'Move event handling to notifications module',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/743',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '4f119651-359d-471e-ba09-648d0f882c62': {'id': '4f119651-359d-471e-ba09-648d0f882c62',
#   'num': '937',
#   'name': 'Tweak mobile toolbar to be open / close instead of edit / view',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1747951958031,
#   'url': 'https://github.com/kosolabs/koso/pull/1120',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '8d6c0e82-5bef-49e3-a41e-3d5c94926022': {'id': '8d6c0e82-5bef-49e3-a41e-3d5c94926022',
#   'num': '382',
#   'name': 'Search should show tags associated with tasks',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1736535418761,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '13bb2b35-ddf4-4547-b86d-03441a6976e2': {'id': '13bb2b35-ddf4-4547-b86d-03441a6976e2',
#   'num': '114',
#   'name': 'Sticky bar not so sticky on Chrome for Android',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'faaee219-eea2-4097-8894-baa849167c79': {'id': 'faaee219-eea2-4097-8894-baa849167c79',
#   'num': '491',
#   'name': 'Add merge-props utility for merging props',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/769',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '090df2e0-1814-472a-a7b9-305c04dca6d9': {'id': '090df2e0-1814-472a-a7b9-305c04dca6d9',
#   'num': '282',
#   'name': 'Show skeletons instead of loading indicators (projects list, dag table)',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '1460207d-d271-4178-80ba-6aa8f4550283': {'id': '1460207d-d271-4178-80ba-6aa8f4550283',
#   'num': '52',
#   'name': 'Limit the size of compacted update rows',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'dea407e3-866a-4ddc-ad5f-c536ded85e32': {'id': 'dea407e3-866a-4ddc-ad5f-c536ded85e32',
#   'num': '1027',
#   'name': 'Remove prefs context from planning context',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1749838052024,
#   'url': 'https://github.com/kosolabs/koso/pull/1180',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '422996f4-c40a-4185-a17c-6611a6fc7e6e': {'id': '422996f4-c40a-4185-a17c-6611a6fc7e6e',
#   'num': '409',
# ...
#   'statusTime': 1746740996241,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'RUXFMDvfTPiUbFwV4zafDw': {'id': 'RUXFMDvfTPiUbFwV4zafDw',
#   'num': '1146',
#   'name': 'Update install steps in the readme',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1753288801969,
#   'url': 'https://github.com/kosolabs/cipherly/pull/74',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'da5a677e-d2d6-4fd1-b729-82241598b94d': {'id': 'da5a677e-d2d6-4fd1-b729-82241598b94d',
#   'num': '327',
#   'name': 'Improve plugins - github',
#   'desc': None,
#   'children': ['207cba11-dcf4-4130-bd6d-7fb19fc9796f',
#    'dffe6d1c-ad0f-42ed-905f-b7bc17974e3c',
#    '6b23104b-1af6-4a18-8a0a-63b34885b042',
#    'b56c9e8b-dbfc-4dd3-be37-e218cc5677c2',
#    '7871b83f-f252-4ea5-a3d8-331da8e20c2c',
#    'dd354c0c-a45c-4eb4-9c69-340476ea275f'],
#   'assignee': None,
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'af649590-3ae1-402c-9c83-579132fa6925': {'id': 'af649590-3ae1-402c-9c83-579132fa6925',
#   'num': '242',
#   'name': 'Make a component out of the Koso logo controllable via the theme',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1729823338098,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'bf5f1629-5ca2-4c16-9cad-adf43214e24a': {'id': 'bf5f1629-5ca2-4c16-9cad-adf43214e24a',
#   'num': '708',
#   'name': 'Revert "Temporarily log headers (#952)"',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1743633014383,
#   'url': 'https://github.com/kosolabs/koso/pull/953',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'pJBBHMI6QR6xqqJDL_V-Ng': {'id': 'pJBBHMI6QR6xqqJDL_V-Ng',
#   'num': '1056',
#   'name': "Use Lucide's svelte5 package",
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1750266081724,
#   'url': 'https://github.com/kosolabs/koso/pull/1202',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '6263a81b-1146-41da-bb0b-c981326fadd5': {'id': '6263a81b-1146-41da-bb0b-c981326fadd5',
#   'num': '563',
#   'name': 'Adjust icon colors for m3',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1741054701494,
#   'url': 'https://github.com/kosolabs/koso/pull/840',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'QncVVqENTZyhMYQbwEXMiA': {'id': 'QncVVqENTZyhMYQbwEXMiA',
#   'num': '1105',
#   'name': 'Validate Telegram messages using a Secret Token',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1752098152166,
#   'url': 'https://github.com/kosolabs/koso/pull/1243',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '8983d777-3c1f-4200-8f3f-f25469a40ff3': {'id': '8983d777-3c1f-4200-8f3f-f25469a40ff3',
#   'num': '727',
#   'name': 'Implement task description markdown view popover on hover of the markdown view button',
#   'desc': None,
#   'children': ['113e9a1a-01c1-4b21-b0ed-04d3df0f4e60'],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '070b83c4-6bb0-421d-b60e-2cec2175556e': {'id': '070b83c4-6bb0-421d-b60e-2cec2175556e',
#   'num': '836',
#   'name': 'Setup uptime checks',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1746799722037,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '99db644b-9dec-4603-8167-703cca3f2652': {'id': '99db644b-9dec-4603-8167-703cca3f2652',
#   'num': '2',
#   'name': 'Reimplement DagTable using HTML table',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '878153bf-8395-4dc8-ae5c-f77d7fb83106': {'id': '878153bf-8395-4dc8-ae5c-f77d7fb83106',
#   'num': '448',
#   'name': 'Update Kosui buttons and links to match Material 3',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127002,
#   'url': 'https://github.com/kosolabs/koso/pull/726',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '518a17b1-ee73-460f-8084-e7079dcfa7c6': {'id': '518a17b1-ee73-460f-8084-e7079dcfa7c6',
#   'num': '313',
#   'name': 'Expose navigation methods over rust graph',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1733359541495,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'cb36f6ba-1241-41fb-81d2-09aa9a27eaab': {'id': 'cb36f6ba-1241-41fb-81d2-09aa9a27eaab',
#   'num': '803',
#   'name': 'Make markdown editor and task / node table independently scrollable',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1746049278536,
#   'url': 'https://github.com/kosolabs/koso/pull/1034',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '3ffcf5b2-32f0-44f4-8ccf-bad8116b50e3': {'id': '3ffcf5b2-32f0-44f4-8ccf-bad8116b50e3',
#   'num': '291',
#   'name': 'Auto resolve tasks when PRs get merged',
#   'desc': None,
#   'children': ['067214a4-591b-4abb-bb36-2cf629a4c828'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': 1749240516387,
#   'url': None,
#   'kind': 'Rollup',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '764a0246-1e36-4f4e-8a57-026249004747': {'id': '764a0246-1e36-4f4e-8a57-026249004747',
#   'num': '970',
#   'name': 'Implement ability to set estimation in the task table of the inbox page',
#   'desc': None,
#   'children': ['a5375518-8ab0-48c9-a5be-5d1dc55d5fbf'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '2afc8a10-7498-4bf9-b59f-b71268e989b4': {'id': '2afc8a10-7498-4bf9-b59f-b71268e989b4',
#   'num': '670',
#   'name': 'Rename TaskAction -> TaskStatus',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1743020022166,
#   'url': 'https://github.com/kosolabs/koso/pull/922',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '39f8e965-ba9c-49f2-8b62-92fa5990da46': {'id': '39f8e965-ba9c-49f2-8b62-92fa5990da46',
#   'num': '734',
#   'name': 'Fix debug print of KosoEvent when deleting a YText field',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744138116594,
#   'url': 'https://github.com/kosolabs/koso/pull/972',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '76245b3f-f681-487e-ba2f-c2d346a78869': {'id': '76245b3f-f681-487e-ba2f-c2d346a78869',
#   'num': '390',
#   'name': 'Modify link/search panels to sort by status',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127001,
#   'url': 'https://github.com/kosolabs/koso/pull/675',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '8c64d620-5a55-41fc-bc25-726f804d0f5a': {'id': '8c64d620-5a55-41fc-bc25-726f804d0f5a',
#   'num': '780',
#   'name': 'Make inbox2 selection and navigation work with filtering',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1744841274188,
#   'url': 'https://github.com/kosolabs/koso/pull/1011',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'a5375518-8ab0-48c9-a5be-5d1dc55d5fbf': {'id': 'a5375518-8ab0-48c9-a5be-5d1dc55d5fbf',
#   'num': '969',
#   'name': 'koso-970: Add deadline and estimate to the frontend',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1748748812841,
#   'url': 'https://github.com/kosolabs/koso/pull/1143',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'QeS2P6qlSfGZkqeks_sLWQ': {'id': 'QeS2P6qlSfGZkqeks_sLWQ',
#   'num': '1219',
#   'name': 'Create Teams OAuth client registration and app manifest configuration',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '8f46141e-f054-43f5-8e92-62888b320462': {'id': '8f46141e-f054-43f5-8e92-62888b320462',
#   'num': '195',
#   'name': 'Speed up playwright tests',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1727741230596,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '85928de4-71b0-41cb-ba41-a1bf0935bdbd': {'id': '85928de4-71b0-41cb-ba41-a1bf0935bdbd',
#   'num': '83',
#   'name': 'Remove / rename Add Root',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'dc1eb73e-9324-409a-b1b0-fe449087577b': {'id': 'dc1eb73e-9324-409a-b1b0-fe449087577b',
#   'num': '950',
#   'name': 'Add videos to the landing page',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1748454141433,
#   'url': 'https://github.com/kosolabs/koso/pull/1131',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '95806b07-e8e4-4b22-986b-e5743e2aad8c': {'id': '95806b07-e8e4-4b22-986b-e5743e2aad8c',
#   'num': '948',
#   'name': 'Update all dependencies',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1748274051057,
#   'url': 'https://github.com/kosolabs/koso/pull/1129',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '3c044062-9f9e-447b-a068-924e5e90b467': {'id': '3c044062-9f9e-447b-a068-924e5e90b467',
#   'num': '72',
#   'name': 'Get rid of ghost and show drop target as a thick line',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'GGg_emIzQQioLGzsOCS83w': {'id': 'GGg_emIzQQioLGzsOCS83w',
#   'num': '1235',
#   'name': 'Update API documentation for Teams endpoints',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'c5dddd93-3aa1-495e-b906-111cdaf9b672': {'id': 'c5dddd93-3aa1-495e-b906-111cdaf9b672',
#   'num': '690',
#   'name': 'Bump teloxide to 0.14',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1743524667134,
#   'url': 'https://github.com/kosolabs/koso/pull/940',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'abe7198b-5a9c-4d9c-9481-553443bbc976': {'id': 'abe7198b-5a9c-4d9c-9481-553443bbc976',
#   'num': '709',
#   'name': 'Export backend logs to gcp or somewhere else',
#   'desc': None,
#   'children': ['dae47536-301c-46d9-a5fa-57da620c07d8'],
#   'assignee': None,
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': None,
#   'statusTime': None,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  'c6c22dc4-4cae-4ba9-9a62-2d3954da4289': {'id': 'c6c22dc4-4cae-4ba9-9a62-2d3954da4289',
#   'num': '638',
#   'name': 'Add a command to organize tasks in the current scope (move done to bottom, in progress to top)',
#   'desc': None,
#   'children': ['9e51ab39-c030-46ea-98ce-ada9f6a9bd50'],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': None,
#   'statusTime': 1743010721836,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'p3Vyj_YbQ6ip_XNhbUFpQw': {'id': 'p3Vyj_YbQ6ip_XNhbUFpQw',
#   'num': '1109',
#   'name': 'Avoid spawning a background task in GH webhook',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1752206579728,
#   'url': 'https://github.com/kosolabs/koso/pull/1247',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '11d8ee95-973c-4dd6-8dc4-f46adec08e61': {'id': '11d8ee95-973c-4dd6-8dc4-f46adec08e61',
#   'num': '219',
#   'name': 'Modifying rust code triggers the dependencies docker layer to rebuild',
#   'desc': None,
#   'children': [],
#   'assignee': 'leonhard.kyle@gmail.com',
#   'reporter': 'leonhard.kyle@gmail.com',
#   'status': 'Done',
#   'statusTime': 1729030026371,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '9d405289-0ce8-4fcb-b36d-8aa51bce2fe8': {'id': '9d405289-0ce8-4fcb-b36d-8aa51bce2fe8',
#   'num': '500',
#   'name': 'Fix shortcut throwing error for unmapped keys',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127001,
#   'url': 'https://github.com/kosolabs/koso/pull/778',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '59264388-0427-4dca-8815-df40cd7ae294': {'id': '59264388-0427-4dca-8815-df40cd7ae294',
#   'num': '511',
#   'name': 'Reduce tooltip complexity to make them less annoying',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740191939206,
#   'url': 'https://github.com/kosolabs/koso/pull/789',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  '1651b217-b3b3-4fd6-87dc-1c5126c8ae04': {'id': '1651b217-b3b3-4fd6-87dc-1c5126c8ae04',
#   'num': '640',
#   'name': 'Add action / context menu to tasks',
#   'desc': None,
#   'children': [],
#   'assignee': 'shadanan@gmail.com',
#   'reporter': 'shadanan@gmail.com',
#   'status': 'Done',
#   'statusTime': 1743100910865,
#   'url': None,
#   'kind': None,
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  '9VQI7vStSiKOmD3YFS242Q': {'id': '9VQI7vStSiKOmD3YFS242Q',
#   'num': '1098',
#   'name': 'initial commit and prop declaration',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1754067721480,
#   'url': 'https://github.com/kosolabs/koso/pull/1236',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': None},
#  'bf0b3290-a46c-43c6-a797-564dcd4c9aac': {'id': 'bf0b3290-a46c-43c6-a797-564dcd4c9aac',
#   'num': '344',
#   'name': 'Rewrite conflicting task numbers',
#   'desc': None,
#   'children': [],
#   'assignee': None,
#   'reporter': None,
#   'status': 'Done',
#   'statusTime': 1740170127001,
#   'url': 'https://github.com/kosolabs/koso/pull/639',
#   'kind': 'github_pr',
#   'estimate': None,
#   'deadline': None,
#   'archived': True},
#  ...}

# %%
for _, task in tasks.items():
    print(task["name"])
# Out:
# Update README with once a day / after every pull instructions
# Configure CI
# Update dependency svelte to v4.2.19 [SECURITY] - autoclosed
# Add support for archiving tasks
# Fixup seats verbiage
# Add more logging when processing anthropic requests
# Update dependabot.yml
# Refactor LinkPanel and TaskStatus to take Task instead of Node
# Open the doors
# Navbar Improvements
# Suppress noisy chrome workspace logs
# Plugin to import review of GitHub PRs as a koso task that resolves when the PR is reviewed
# Disable Delete action in inbox
# Bump mode-watcher to 1.0.0
# Move telegram notifications out of deploy.sh into the github action using appleboy/telegram-action
# Cmd+Shift+Option+Enter should create a new child in previous task
# Markdown editor should wrap text
# Improve socket shutdown handling
# Try setting the exact install version
# Fix dark mode for the editor
# Fix several lint warnings
# Create a test that ensures various widths of browsers have no scrollbars
# Nodes should only expand after a delay when dragging
# Handle juggled tasks in toggle status
# Fix task deep links
# Simplify render delegation by using useRef callback instead of element box
# Adopt tailwind-variants in Kosui
# Refactor status, kind and progress handling
# Display badges for premium members
# project-share-modal.svelte
# Downgrade to rust 1.86
# Break circular import deps
# Uses enum style constants for ActionIDs instead of relying on types
# Bump the npm-deps group across 1 directory with 13 updates
# Handle selection when tasks disappear
# Make action item tooltip clearer
# aAdd note about remote server
# Add commands to cycle between the nodes of a task
# Experiment fixing Svelte bug
# Usability
# koso-741: Always show the markdown viewer / editor even if a task is not selected
# Migrate Input, Textarea, and Alert components to kosui equivalents.
# Add all Input variants and Scale parameter to Kosui components
# Add support for floating tasks
# Try fixing down cast
# Add integration tests for collaboration
# koso-853: Add a `rich` flag to Tooltip component for styling Rich Tooltips
# Implement client side warnings when schema is off
# Add support for GitHub reference links
# Add action to copy task permalink to the clipboard
# Promote Chips to Kosui
# Bump openssl from 0.10.68 to 0.10.70 in the cargo group across 1 directory
# Add a category field to help organize the command palette
# Archive
# Update secondary colors to provide a nice contrast
# Update all dependencies
# Use project context in task detail page
# koso-910: Fix premium crown causing horizontal scroll
# stylable markdown
# Create Teams app registration documentation
# Bump the docker-deps group with 2 updates
# circular-progress-status
# Run clippy over tests
# Add support for mermaid diagrams
# Refactor Kosui autocomplete component to use a Svelte context
# Update all dependencies
# Add uncontrolled flag to Menu to disable close onSelect
# Make Navbar available on all pages
# Svelte 5: Migration
# Implement render delegated version of Kosui menu
# Add our first UI interaction test
# Add experimental support for mermaid diagrams
# Write an integration test
# Fix "Take me home" dialog escape
# Try a different environment variable name for publishing
# By default, tasks that have children should show progress for status
# Correct multi-ecosystem-group pattern
# Update pnpm to v10.8.1
# Add type for awareness update
# Fix static content links to work for unauthenticated users
# Add a cool UI effect when a user earns points
# Add Teams integration tests
# Delete shadcn-svelte dropdown-menu component
# Add task size estimate field that defaults to days in Fibonacci
# Stop using node in organizeTasks
# Rename Row -> DagRow to match TaskTable / TaskRow
# dag-table/table
# Use the success toast variant
# Remove old images from github containers
# Split planning context tests from koso tests
# Creating a new project errors on first load with "Error: Task ID <ID> not found in yGraph"
# Move event handling to notifications module
# Tweak mobile toolbar to be open / close instead of edit / view
# Search should show tags associated with tasks
# Sticky bar not so sticky on Chrome for Android
# Add merge-props utility for merging props
# Show skeletons instead of loading indicators (projects list, dag table)
# Limit the size of compacted update rows
# Remove prefs context from planning context
# Add a telegram bot server to serve tokens
# Expand toggle is shown when no children are visible due to archiving
# Prototype Node using Immutable.js
# Heartbeat monitor server
# Run integration tests in GitHub actions
# Restrict usage of the parent global
# Video of a GitHub PR automatically being linked in the graph
# Remove Kosui dependence on tailwind-variants
# Make lint, check, etc the same as Koso
# Add endpoint to fetch the project's LLM context
# Dragged node remains after dragging ends sometimes (switching windows, drag out of collapsed children)
# responsive-text
# Should rollups show up in inbox?
# Allow file reupload after clear
# Make the setup flow more robust
# koso-4: Working on testing 1
# Implement front end handling of external tasks
# Stop pulling the github repo onto the deploy host (koso.service needs transferred)
# Run ci as part of deploy with reusable workflow
# Add Avatar to the Navbar
# Add a search bar to search for tasks and select rows
# Update all dependencies
# Enable Kosui menu to handle up/down arrows
# koso-894: Populate PR authors on tasks
# build(deps): bump docker/build-push-action from 6.17.0 to 6.18.0 in the github-actions-deps group
# Add a Reason column to the Zero Inbox
# Do full screen confetti when task is marked done
# Make sure confetti doesn't abruptly disappear
# Revert "Update all dependencies"
# fix(deps): update all dependencies
# Add global frontend error handling to avoid the white screen of death
# build(deps): bump reqwest from 0.12.15 to 0.12.18 in the cargo-deps group across 1 directory
# Refresh Google oauth certs dynamically
# Fix task auto organization being too jarring due to too much movement
# Configure renovate
# Set permissions on workflows
# Implement setup flow
# Make kind hierarchy handling robust in the face of interesting names
# koso-1036: Sort tasks in Inbox by Status first, then Score
# Buttons to move tasks up / down
# Select Menu item by typing menu item text prefix
# Use the root getter
# Should task status progress numbers show in progress and not just done?
# Get rid of the old command-palette component and the action registry
# Clicking escape on nested popovers should close in reverse order of open (see share dialog and self-removal)
# Create an OrderedHTMLElements class to help with focus management
# Setup dockerfile
# Limit the number of connected clients for a given project
# Add creation and login timestamps to users table
# Force reload of a client if they aren't running the latest code
# Fix bug with select next link, add bounds checks
# awareness
# Add some tweaks to the action item reason text
# Propagate errors instead of panicking
# Link panel should allow linking to the Root
# koso-1029: Avoid showing expand toggle when no children are visible
# Base64 URL encode task IDs
# Add Teams configuration to deployment scripts
# Backend Improvements
# Integrate with Github webhooks
# Make clicking on the logo go to projects page
# Implement Telegram notification configs and wire-up Telegram auth
# Use different lib names to avoid name conflicts
# Changing status should move tasks to the boundary of their block
# Rework progress kind
# Bump the github-actions-deps group with 3 updates
# Double click on Markdown button toggles the viewer
# Generate project status summaries
# Use goto for fast nav to tasks
# Link a task as a child of another task by searching
# Make a flaky flag that skips flakes
# Add pagination for installation repos
# Update backend to funnel updates through observer
# Validate Discord timestamp is fresh and print request and response headers in debug
# Add collab tests for task description editor / viewer
# Add MenuActions componenent and migrate Profile, Nav, and TaskAction menus
# Reject duplicate client entries outright
# koso-902: Add more SW logs
# Enable actions to be invokable globally
# Verify table undo/redo on Windows
# Add Teams permissions and scopes configuration
# Hamburger menu should not be visible when there are no items in it
# Move the context menu to show up to the left of the Koso logo
# Put the commander context into a class
# Batch sending messages to clients if throughput is an issue
# Implement medium screen view of dag table (phone landscape)
# koso-727: Show markdown preview when hovering markdown view / edit button
# koso-925: Implement workflow: block on -> new task -> assign to someone else
# Fix viewport and confetti jumping when marking task Done
# Move the deadline column behind the debug flag and make estimate small
# Add Teams notification settings to user configuration schema
# Implement restore project from trash
# Contextify auth
# Make the name column full width
# Tweak button styles to make Icon buttons simpler
# Integrate Stripe billing and subscription management
# Style Modal component and start separating base styles
# Moves marked from devDependencies to dependencies
# Collapsing or expanding nodes causes viewport to scroll to selected task
# Rework status icons to have consistent colors
# KTLO
# Beautify the dashboard a hook it up to navigation menu and task actions menu
# chore(deps): lock file maintenance
# Add kosui link, buttons, and breadcrumbs
# Backup monitoring
# Milestone 1: Ready for our first alpha customers
# Bump svelte, vite, filesize, and zod to latest
# Blocked handling
# Add button on tags to remove it
# Onboard
# Install rust toolchain
# Reduce shutdown signaling to a single cancellation token
# Display the user's badges on the profile page
# Refactor drop zones to support scrollable panels
# Implement profile page with Telegram config
# Reintroduce selection based on tasks instead of node
# koso-934: Make task detail workflow better
# chore(deps): update all dependencies
# The premium crown causes horizontal scroll
# Export function from utils
# Add commands to the command palette to toggle the theme
# Migrate UserSelect component over to Kosui Menu
# Update all dependencies
# Refactor Menu to use a Svelte context
# Improve environment variable defaults
# Data Source Plugin
# Video of dragging and dropping tasks to create a dependency graph
# Create Teams authorization flow endpoints (connect/disconnect)
# Lock file maintenance
# Install rust toolchain if not installed
# Add a tooltip for managed tasks
# Link task should not be visible when no task is selected
# Split Dialog component into Dialog and Modal
# koso-917: Make task action buttons consistent and fix clipping
# Kosui menu deselects menu item when mouse leaves
# Add inbox status icon and link to project
# Configure pnpm's use-node-version
# Lock file maintenance
# Add a priority field
# Organize code in anthropic.rs and fix vuln in slack.rs
# Linking a GitHub PR to a task causes the task's estimate to be overridden by the managed task's non-existent estimate
# Add promotional text
# Bump the "all-deps" group with 2 updates across multiple ecosystems
# Change 'insert' label to 'add'
# Simplify tailwind CSS for buttons and links
# Simplify MarkdownEditor using the new YTaskProxy store
# Reimagine the Inbox
# Update all dependencies
# Remove context actions from toolbar
# Implement import
# Apply workspace Cargo.toml file to docker builds
# Bump the "all-deps" group with 2 updates across multiple ecosystems
# Persist state of collapsed / expanded nodes
# Fixup a few oauth bits
# Anvita tasks
# Fixup healthz teloxide change
# Migrate command-palette to Kosui component
# Sending tasks to the child of another task should intelligently place the task based on its status
# Add basic tests for Kosui buttons
# Make command-palette and link-panel more beautiful
# Add score to tasks in the inbox
# UI tweaks - drag handle, m3 colors in table, avatar fallback
# Fix padding on Inbox to make selection highlight less janky
# Tweak navbar nav menu and restore toggling navigate buttons
# Improve backend error handling
# Update dependency @sveltejs/kit to v2.20.6 [SECURITY] - autoclosed
# Migrate off of bits-ui
# Create Teams notification message formatting and sending logic
# Use Kosui Tooltip for ManagedTaskIcon
# Undent/indent show twice in the command palette and break scroll
# Migrate renovate config
# Update components to be strictly dependent on Svelte and not SvelteKit
# Force runes mode for all project svelte files
# Update dependency vitest to v3.0.5 [SECURITY]
# Make offline mode great again
# Enrich error logging with context
# Explicitly store a shutdown status
# Round out the bottom left and right of the dag and task tables
# Add support for breaking down tasks using Claude
# Add Fab flag to reserve space so that you can scroll past content to show fab by itself
# Use Svelte Store to enable reactivity on YTaskProxy
# Cleanup debug log
# Add shift to the Copy Task shortcut because existing shortcut conflicts
# Set patterns on all updates
# Bump the npm-deps group across 1 directory with 12 updates
# Tooltips for what will happen when you drag and drop
# Improve usability of context actions
# Restructure plugin configs to be project oriented
# Bump ring from 0.17.11 to 0.17.13 in the cargo group across 1 directory
# Bump the github-actions-deps group with 2 updates
# Add docs about telegram secrets
# Handle rollup tasks in the juggler notifier
# Update dependency vite to v5.4.19 [SECURITY] - autoclosed
# Rewrite task "num" field in the backend to resolve conflicts
# Log even more error messages on healthz check failure
# Show tooltip on task status (the text itself may be hidden on mobile)
# Sort tasks by the score field when executing the organize task action
# Reorganize a few koso methods
# Use Koso context accessors
# Remove unused cargo deps
# Better debug: set `localStorage.dev = true`; toggle debug in the command palette
# Make tasks property reactive
# Blocking a task on another using link-panel sets kind to Juggled
# Make Github app public
# Move library function out of index.ts
# Store oauth clients in postgres and support auth method "none"
# Remove teloxide from healthz checker
# koso-868: Render Markdown links nicely
# Remove unused import
# Update all dependencies
# Task selection cuts off left and right selection highlight
# Introduce TaskLinkage
# Add marketing for the zero inbox
# Bump various rust deps and fixup octocrab interaction
# Add a reason field to represent the reason why a task is assigned
# Move status column to be between ID and Name and hide column header in mobile view
# Remove patterns from group def
# Add ability to set project name
# Fixup postgres version refs
# Configure stripe branding
# Use Kosui Tooltip for DropIndicator
# Avoid warning when clients reset connections
# Add tailwind styles that implement Material 3
# koso-755: Support dark mode in CodeMirror
# Combine command-context and autocomplete-context into item-context
# Task detail panel and task list should be independently scrollable
# koso-1033: Fix organizing tasks with Ready present
# Close Menu on click outside
# Implement ProjectContext to enable re-use of Koso and Socket across pages
# Configure Renovate - autoclosed
# Gracefully handled suspended or uninstalled installations
# Add ability to set assignee
# Empty dag table hint not visible in dark mode
# Improve stream handling client side by buffering lines
# New kind on task, replace status button with type toggle (rollup, juggle)
# Update all dependencies
# Map GitHub users to Koso users
# Reintroduce tags that link to various versions of the task in the project planning view
# Confetti shows up behind rows in the planning view
# Move tasks within blocks
# Avoid accidentally holding mutexes longer than expected
# Implement search for tasks - ⌘ + P
# Correctly handle unmanaged kinds
# Accept single x-fowarded-for values
# Implement Juggler that reassigns tasks when they become actionable
# chip
# Fix 429 errors when fetching user images for avatars
# Move deps to dev deps
# When interacting with a component, disable keyboard bindings
# Bump the docker-deps group with 2 updates
# Handle rollup tasks in inbox
# Implement full history of a Koso project
# Fix double scrollbar in link panel
# Fix racy tests exposed by playwright
# Polish
# Awareness should show some indication when a user has selected a child
# Avoid depending on mode to decide on the github app
# Delete Zero and merge kosolib with koso
# Projects page tests
# Changing task status shouldn't move tasks around
# Make tooltips narrower for mobile drag and drop by reworking the text
# Fixup svelte eslint warning
# Different color drop target depending on whether drag and drop will add as peer or child
# Consolidate toolbar code into one component and rename table -> dag-table
# Websocket stays open across mount/unmounts; need to unmount connections or reuse
# Use image digests
# Move project related components out of lib folder
# Delete AI Rollup as a coming soon feature
# Improve Github plugin logging
# Initial implementation of Koso UI (kosui)
# Undo on a new project will undo creation of "root"
# Add Koso task number to GitHub PR to link PR to Koso task (koso#<ID>)
# Configure panics to abort the process
# Add trait to ease converting errors into error responses
# Make tooltips show up with long press on mobile
# Use a state machine to manage toggle state
# build(deps): bump brace-expansion from 1.1.11 to 1.1.12 in /frontend in the npm_and_yarn group across 1 directory
# Remove single-use transactions
# Intelligent sorting of tasks in the Zero inbox
# Allow deleting projects (move to trash)
# Tooltips can be cancelled by dialogs opening and closing
# Short circuit graph iteration when all references are found
# Scalability
# Add Teams notifier to the notification dispatch system
# Let pnpm manage node version
# Implement notifications via Microsoft Teams
# Tweak renovate timings
# Avoid recounting the same tasks when calculating Progress
# Update notification event observers to include Teams dispatch
# Handle out of order events
# Persist undos across page refreshes
# Fix a few billing bugs and add tests
# koso-138: Implement collaborative task description viewer and editor
# Fix staggered spacing when task name wraps
# Fix outline bug in Safari
# Lock file maintenance
# Show dag-table and task-table header icons in desktop mode as well
# Migrate from Rocket to Axum
# Auto generate subtasks based on task detail
# Scroll command items into view When navigating with arrow keys
# user-avatar
# Allow Rollup as an explicit Kind
# Add nice env vars
# Avoid trying to close connections we already know are closed
# Add generic type parameter to toggle buttons
# Send notifications when tasks become actionable
# Clean up database after integration tests
# Backlog
# Tweak test message to use location.origin
# Update all dependencies
# Refactor Kosui menu component to use a Svelte context
# Move Portal component over to Kosui
# Investigate koso freezing
# Integrate stripe
# Update all dependencies
# Closing the link panel should clear the filter text
# editable
# Update frontend dependencies
# Establish public interface by adding exports to index.ts
# Linking a GitHub PR by referencing a koso task does not link if the task kind is Task
# Server endpoint /healthz
# Refactor plugin config settings representation
# Convert several pages to runes mode to avoid Svelte bug
# Update all dependencies
# Validate Slack messages using the Signing Secret
# Projects page
# Degrade to read-only mode when too many clients are connected
# Includ rollup tasks with unassigned children
# Enable spreading of ref callback during render delegation
# Task action buttons are not all the same size and the right side clips
# Create a CLI that reads a binary YJs update and produces the JSON
# Display number of days that a user has been on a streak
# koso-902: Stop using deprecated stores
# Fix build warnings on code-mirror
# Improve perf by computing current iterations only once instead of once per task
# Add syntax highlighting for codeblocks in markdown view
# Add tests for setting task status and setting assignee and reporter
# Use service account impersonation instead of keys
# Rename 'insert' to 'add'
# chore(deps): update all dependencies
# Add payment processing
# Dedupe postgres environment variables
# Update dependency vite to v6.2.6 [SECURITY] - autoclosed
# Split Tooltip component into Tooltip and Popover components
# Bump the cargo-deps group across 1 directory with 4 updates
# Broadcasting holds a clients updates lock serializing broadcasts for a project
# koso-894: Add the ability to connect a Koso user to Github
# Improve selection handling
# Factor out user authorization
# Bump vite from 6.2.4 to 6.2.5 in /frontend in the npm_and_yarn group across 1 directory
# Add dark mode toggle to profile menu
# Require iss and aud claims
# When collaborating, if person A is editing a field, editing will get cancelled if person B stops editing some other field
# Bump openssl from 0.10.71 to 0.10.72 in the cargo group across 1 directory
# Square off buttons to look more like JoyUI
# Tweak eslint config to avoid parsing error on .svelte.ts files
# Protocol Improvements
# Add Yrs proxies for all interactions with the YGraph
# Clicking to edit a task causes the view port to jump to top of page
# Client poller
# Configure Renovate - autoclosed
# Update database schema to support Teams notifier configuration
# Implement Teams API client with authentication handling
# Add middleware to log request and response bodies in dev mode
# Fix flickering of rows in Safari when expanding / collapsing tasks
# Add debugging to see protocol error
# Migrate back to shadcn-svelte
# Set TimeoutStopSec to bound restart time
# Use underscores to generalize the kind hierarchy
# Avoid extending the lifetime of refresh tokens beyond the original expiry
# Clicking task names in the Inbox navigates to corresponding task in Plan
# Remove unnecessary vite override
# Migrate avatar profile menu to Kosui
# Provide a stronger visual indication of which page you're on Planning / Inbox / Executive
# Introduce user preferences context and make detail panel state a pref
# Toolbar remains in "task selected" mode after undoing creation of a task
# Set cache-control headers on _app/immutable files
# Simplify ActionItemTooltip to be just a clickable tooltip
# Resimplify awareness handling
# Fix markdown rendering glitches when a collaborator is editing the markdown
# Move koso.svelte and socket.ts into dag-table
# Clear command palette and task search on close
# Add components to setup and tidy
# Fixup a couple of unwraps
# npm bug: `npm ci` can only install packages when your package.json and package-lock.json
# Avoid leaking database pools in tests
# Use the Kosui button throughout Koso
# Make drag element better looking
# Add tooltip prop to Button component
# Focus shifts after scrolling away from a selected a node and expanding a collapsed node (or editing a task)
# Reorganize queries by domain
# Run E2E tests against docker image
# Add ability to force refresh of local state in indexedDB
# Add Kosui component for rendering Markdown
# Update Rust crate tokio to v1.38.2 [SECURITY] - autoclosed
# Make task name editable to match planning page
# Task Management Plugin
# Lock file maintenance
# Delete last of shadcn-svelte components and remove bits-ui dependency
# Milestone 7: Human Resources
# koso-900: Bootstrap inbox tests
# Milestone 2: Demo to Lexi Quirk
# koso-285: Create initial implementation of the executive dashboard
# Update notifiers with settings variant
# Improve typing of github state
# koso-1001: Add a Ready status to mark a task as Ready for Work
# Add buttons to navigate between Project Planning and Zero Inbox
# Bump the npm-deps group across 1 directory with 12 updates
# Automatic developer performance evaluations
# koso-856: Make tooltips wrap when they get too long
# Add support for notifications in Discord
# Add task status with fireworks
# build(deps): bump node from 24.0.2 to 24.1.0 in the docker-deps group
# Update Zero icons
# Dejank popovers like tooltips and project share modal search
# koso.ts → koso.svelte.ts
# koso-916: Add edit and view buttons to task detail preview tooltip
# Make github links bidirectional (modify the PR to link to the koso task in description and tags)
# Implement the undo manager
# Auto-assign to assignee of parent task
# Simplify Command component by using a state context
# Remove `koso/` from paths in README stripe instructions
# Add a different action tooltip message for managed tasks
# Task detail preview tooltip should include an edit action button
# Stop using node in many places in koso.svelte
# Drag and drop to child now highlights the row
# Update all dependencies
# Rename days to points in estimate and add a tooltip
# Heartbeat monitor client
# Configure npm authToken in deploy to avoid warnings in CI
# Create a user selection component
# Purge projects from the trash that are older than 30 days
# Compaction may not keep up with the rate of updates for large projects
# Use strict equality
# Cannot find base config file "./.svelte-kit/tsconfig.json" in docker build
# Fix hard to click expand / collapse button
# Update all dependencies
# Marking a task as In Progress should move the node to the top and assign to current user
# Fix typo in cache from name
# Toast users when blocking or completing tasks
# Use small icons for status and assignee column headers in mobile view
# GitHub
# Add landing page screenshots
# Fix base styles to work with Menu Items
# Fix placement of Add Task FAB and improve task / detail layout proportions
# Add a script to login with a test user
# Make inbox2 the primary inbox
# Ready now removes task from Inbox and managed tasks show different action to resolve
# Reorganize layers
# Bump the cargo-deps group across 2 directories with 4 updates
# GitHub PR
# Configure vscode settings
# Drop zones are incorrect when row heights aren’t a single line
# Apply fixes for eslint svelte v3
# Creating a new task should start editing by default
# Bump the cargo-deps group across 2 directories with 1 update
# koso-896: Add action to copy task permalink to the clipboard
# Prompt users to log in in response to 401 errors
# Support task detail panel being shown side-by-side on large screens
# Implement kosui tooltip and apply to existing buttons
# Stop using node in visibility filter
# Delete unnecessary types RowType and TaskActionType
# koso-729: Add syntax highlighting for code blocks in markdown view
# Add Teams webhook endpoint for receiving interactive commands
# Move remaining node bits
# Use the same port for playwright and host setting
# Upgrade components
# Refactor drag and drop to use methods from koso
# Improve test DB cleanup
# Single task view for detail
# fix(deps): update all dependencies
# Score: Add a score to tasks and keep track of a user's score (total, per week, per day) and grant a badge based on stats
# Add clickable flag to Tooltip which shows Tooltip on click instead of on hover
# Replace stateful #items with regular array in OrderedHTMLElements class
# Copy links into landing page
# Beautify and use toasts consistently everywhere
# Keyboard bindings for all buttons
# Set login_time on first login
# Bump the docker-deps group with 3 updates
# Add parent tags to inbox2
# Toolbar shows vertical and horizontal scrollbar
# Remove duplicate outline class
# Enable deep-linking tasks by passing a taskId query arg
# Disable tracing for static files
# Simplify tailwind.config.js and abandon custom radius theme
# Add global event manager to correctly order and handle DOM events
# Show tooltip on status hover
# Add keybindings to view / edit task description markdown
# Aggregate tasks show "Not Started" even when some children are in-progress
# Limit the number of connected clients  globally
# Migrate configs
# Add instructions for setting up local development of Slack and Discord
# Fix flaky websocket test due to awareness
# Allow tasks to be juggled by another task and reassigned when actionable
# Simplify signature verification
# Implement deactivation flow
# Add a child should expand parent
# Inbox zero is achieved when all triage and actionable items are done
# Design doc for https://github.com/kosolabs/koso/
# Update all dependencies
# Migrate to updated version of shadcn-svelte
# koso#3: Create testing.md
# Remove opacities to improve performance and create a perf page
# Migrates Button and Badge components from shadcn-svelte to kosui
# Add estimation of tasks in the most recent iteration to reasons in the Inbox view
# Tidy up the command component
# Avoid flash of default content when loading project
# Convert Koso to a Progressive Web App
# Fix the AI slop in the Discord code
# Implement export
# Convert healthz checker to axum service for use in Cloud Run
# Remove extraneous autofocus props
# Delete button that deletes the entire subtree
# Log error messages on healthz check failure
# Bump the npm-deps group across 2 directories with 7 updates
# Clickable tags don't work
# Fix the detail panel close button
# Add version header to websocket connections
# Rendering a link in Markdown shows no indication of the link
# Adopt anyhow error
# Add button in mobile view to show markdown and fix horizontal scrolling issue
# toolbar-button
# Display the user's score (total, per iteration, per day) in the Inbox somewhere
# Show ready tasks when all other tasks are done and show confetti when inbox zero achieved
# Plugin for GitHub issues
# Add an MCP OAuth playwright test
# contextify dialoguer
# Temporarily log headers
# Clicking assigned, reporter or status drop-down on mobile takes 2 clicks
# Migrates Goto component from kosui to local implementation
# koso-648, koso-959: Add estimate and deadline fields
# Tweak settings logs
# Tags
# Make "tags" clickable
# fix(deps): update all dependencies
# Task status needs a datetime
# Consolidate unauthorized dialog to +layout.svelte
# Limit the duration of a client connection
# Gamification: Incentives for Engineers
# Update all dependencies
# Add support for Basic client auth
# Bump cargo deps
# Implement our first server side validation
# Refactor MenuItem so that it doesn't need a menu reference
# Move @floating-ui/dom to dependencies
# Update all dependencies
# dag-table/row
# Create a class for Actions
# Add Teams OAuth flow initiation in the frontend
# Create a task detail view placeholder
# Use Avatars for Reporter and Assignee
# Add more padding to link panel task IDs
# Keyboard shortcuts should be disabled while editing
# Migrate Toggle from shadcn-svelte to Kosui
# Organize CI steps nicely and fix typos
# Adopt MenuActions in the Status Menu
# Allow task name to be edited using the detail panel
# user-select
# Separate link panel into node and task variants
# ⌥+⇧+Down should move task to the bottom
# Add tooltip for managed tasks
# Remove debug log
# In mobile mode, task context menu should appear on the mobile taskbar
# chore(deps): lock file maintenance
# Promotional landing page describing Koso’s mission
# Replaces Card component with kosui Box component
# Wrap toast in a popover so that we can show them over dialogs
# Inbox page tests
# Consider making Meta+up/down cycle through non-expanded nodes
# sonner
# Correct status comparison to avoid generating spurious updates
# Fix parse error due to esrap when running locally
# Prototype task dedupe using OpenAI embeddings
# Tooltips should appear above the table header
# Adjust log levels
# Make reason tooltip max 80% width of screen
# Replace landing page images with dark mode ones
# Update all dependencies
# Update all dependencies
# Modifying a GitHub PR's title after it has merged leaves the task "In Progress"
# Experiment
# Update all dependencies
# Polish frontend handling
# Delete shadcn-svelte Tooltip component
# koso-895: Really fix task deep links
# Stop using node for insertNode
# Create demo videos of highlighted features
# Refactor Actions to be owned by Commander
# Update all dependencies
# fix(deps): update all dependencies
# Add a cute 404 and error page
# Create Teams webhook signature validation
# Reliability
# Add ability to set task kind to Iteration
# Fixup usage of deprecated type
# Enable pnpm's strict-dep-builds
# koso-1008: Add support for archiving tasks
# Bump vite from 6.3.2 to 6.3.4 in /frontend in the npm_and_yarn group across 1 directory
# Create a compacted view over yUpdates
# Plugin for //TODO comments in a codebase
# Simplify Github app config
# Migrate shadcn-svelte's Avatar to Kosui
# Setting project name to empty fails silently
# Use Kosui Tooltip for Awareness
# YJs Explorer
# Polish the task editor
# Identify and invoke actions using a type-safe ID field
# Use exactly name matches to avoid flakes
# Add streaming responses from anthropic endpoints
# Update all dependencies
# koso-709: Support multiple log formats, e.g. json
# Bump the "all-deps" group with 2 updates across multiple ecosystems
# Prevent password managers from prompting to fill the name field
# Run migrations in run_dev.sh and change default db url
# Fulltext description
# Reuse octocrab client
# Update notification settings UI to include Teams toggle
# Planning page tests
# Setup development and prod Github app and secrets
# Project should show active collaborators, even if they don't have a task selected
# Put the navbar menu everywhere that the taskbar exists
# Done tasks should move to the bottom
# Add navigation commands to the command palette
# Enable graceful shutdown of telegram bot
# Bootstrap tests for inbox
# Icons for dark and system themes in the command palette are incorrect
# npm run check: Unknown property: 'cy' (css) (cx, cy, r)
# Pressing shift enter while editing a task should save the existing task and create a new task
# Contextify CommandPalette
# Use Promises instead of Svelte State for sync state
# Maintain query parameters when redirecting on login
# Toasts in zero inbox
# Add option-shift indent/undent
# Add handlers for Home and End buttons
# Support for auto generated test users in integration tests
# Update README.md
# Add new inbox landing page
# Move the github app code into github plugin
# Add MCP oauth support
# Put components in a sidebar
# Add support for mapping a repository/install to multiple projects
# Fix wrapping of name field when table is narrow
# Fix Editable not using the full width
# Update all dependencies
# Update Dialog component to use bindable open prop
# Navigate to the task itself rather than just the parent
# Implement project sharing
# Research oauth flow
# Bump the cargo-deps group across 1 directory with 2 updates
# Log close errors
# DRYify merging of event handlers
# Add command to navigate to the Dashboard
# Add autocomplete component and use in share project modal
# Enable unwind tables for better backtraces
# Dedupe tasks via Zero inbox
# Rename juggle and block kind and status
# Show a congratulations alert in the Inbox when the only tasks are Actionable tasks
# Fix dialog box not triggering onSelect when clicking outside
# Fix image caching
# Scrollbar width test
# Fix formatting in poller
# Add screenshots
# Keep markdown viewer / editor open even if nothing is selected to prevent jank when dragging and dropping
# Bump the docker-deps group with 2 updates
# Prevent assignee, reporter, and status text from wrapping
# Promote Shortcut and Shortcut badge to Kosui component
# Add issuer to notifier claims
# Use new Material 3 dialog in Telegram authorization
# Delete the semver check
# Flip price to the live account
# Bump the npm-deps group across 2 directories with 6 updates
# Action buttons should be visible even when table is scrolled
# Attempt to fix auth related crashes
# Show unassigned children of assigned rollup tasks
# +layout.svelte
# In mobile view, only have symbol in view for status
# Use github pr issue state instead of action
# Update all dependencies
# Stop using node in setTaskStatus
# Hoist layout of tasks / nodes and detail panel up to +page
# Lower the collab stop timeout
# Remove button animation from tasks
# Add subscription e2e tests
# Replace unmanagedKinds
# Enable playwright caching
# Bump reqwest from 0.12.11 to 0.12.12 in the cargo-deps group across 1 directory
# Bump mode-watcher
# Telemetries
# Koso Agent: AI Project Manager
# Make task name editable from the detail panel
# Adds basic end-to-end testing with Playwright
# Fix inconsistent dragging (sometimes dragging doesn't drag)
# Implement inbox using dag Table component
# Add an export command to the command palette
# Bump tailwind-variants
# MVP Workflows: Engineers, Product Mangers, and Executives
# Ability to perform actions on more than one task at a time
# Storyboard the videos
# Implement inbox2 deletion
# Investigate poor performance during rendering
# Update all dependencies
# Fork the dag-table into TaskTable and TaskRow
# Update dialog to Material 3
# Notifications: Notify users when something is assigned to them
# Simplify authorization error handling
# Use pnpm to manage its own versions
# Bump @sveltejs/kit from 2.20.5 to 2.20.6 in /frontend in the npm_and_yarn group across 1 directory
# Fix unknown property cx, cy, r in pnpm check
# Organize tailwind classes in Kosui components
# Add renderer for formatting table cells
# Lock file maintenance
# Milestone 6: Add Cipherly to Koso Labs
# Give toolbar buttons an animation
# Bump to svelte 16.3
# Cmd+Shift+Enter should create a new task above
# Add Fab for adding tasks and remove toolbar in desktop mode
# Milestone 3: VITO (Very Important Top Officer)
# Validate billing redirect URLs
# Video of the Zero Inbox showing assigned tasks and notifications when tasks become actionable
# Tooltip should wrap when the content is wider than the viewport
# Dropdown menus shouldn't hold focus after they are closed
# Fix GitHub and GitHub PR looking disabled and connect to github button styling
# Make commander more ergonomic and move palette to navbar
# Implement an API for tasks
# Add Due Date to Dashboard and make On Track / At Risk reactive
# Tasks that are part of the critical path should show up in the engineer's inbox to get estimated
# Migrate from flowbite to shadcn
# Option shift should move tasks to the boundary of the current block
# Rename Juggled kind to Task
# task-status-icon
# Update colors to match logo's new blue
# Begin migration to Kosui
# Move Navbar buttons to new Project Menu
# Convert Autocomplete to use Svelte context
# Add scroll bar to project-share user select in case of many users
# Ensure origin is always set on mutable transactions
# Refactor yUpdates table to be append only
# Bump the "all-deps" group with 2 updates across multiple ecosystems
# Provide URL to a node to enable discussions outside of koso
# Toggle to show done tasks
# Create a context menu for each task
# Consider compressing API responses: https://github.com/kosolabs/koso/pull/327
# Buttons to indent and undent tasks
# koso-894: Add an update user endpoint
# fix(deps): update all dependencies
# Add support for generating design docs based off of a repo
# Make Taskbar beautiful on mobile (wrap, smaller, add tooltips)
# Reset size overrides used in various places
# Nudge user to try the command palette shortcut
# koso-863: Add action to copy a task's git commit message to the clipboard
# Avoid conflating null and false + more yproxy tests
# koso-852: Markdown editor wraps text
# Add block-on toggle to Link Panel and make it default in Inbox view
# Rename projects.id to project_id
# ⌥+⇧+Up should move task to top
# Plumb errors from each server to main
# koso-902: Instrument service worker and workbox with more logs
# Use the new dialog to implement the Unauthorized Dialog
# Task description markdown viewer / editor should open side-by-side in desktop mode
# Add Teams-specific error handling and logging
# Rewrite dialog to work in Safari
# Bump the npm-deps group across 1 directory with 3 updates
# koso-842: Fix markdown rendering by setting token each loop key
# Organizing tasks throws Invalid status Ready when Ready tasks are present
# Enable playwright caching
# Upgrade bits-ui
# Fix downcasting of protocol errors
# Anchor project with a top level root node
# chore(deps): lock file maintenance
# Update all dependencies
# Upgrades kosui to v0.0.10 and uses its Skeleton component
# Camel case a few function names
# Prototype chips for representing alternate parents
# Inbox Actionable tasks should sort by Status
# Handle showing/hiding "progress" tasks with children that are done (or not)
# Avoid showing blocked juggled tasks in the inbox
# Experiment
# Fix error_description key
# koso-3: Update testing.md
# Delete Kosui's cn() and rely solely on tailwind-variants / twMerge
# Tag height should be fixed
# Run CI tests inside of our docker container
# Retry drag and drop tests
# Add WAI-ARIA compliance tests for Kosui Menu
# Derive estimates for rollups
# Rename status: Blocked -> Juggled, rename kind: Juggled -> Task
# Fixup a few bits of documentation
# Use settings files to configure backend
# Update all dependencies
# Use @lucide/svelte
# Zero inbox
# Drop target should indicate the level at which the dragged node will be dropped
# Spacebar should toggle task status
# Add a playwright test for billing, including going through the stripe portal
# Add a fallback avatar image and title to the navbar
# Allow Fab classes to be customized and tweak layout on dag table
# Rename toggle-state to toggle-context
# koso-1030: Fix confetti z-index
# Create toggle buttons for use in Link Panel
# Link panel integration tests are flaky
# Tailwind 4
# Show status and tags in search/link panels
# Search should sort by task status
# fix(deps): update all dependencies
# task-status-select
# koso-4: Do the things
# build(deps-dev): bump the npm-deps group across 1 directory with 11 updates
# Reorganize markdown editor -> DetailPanel, viewer -> MarkdownViewer
# Add support for selecting Auto-* kind
# Add scrollbar test for Inbox page
# Put WebSocket logs behind the debug flag
# Fix chip's delete button also trigger click
# Done tasks should eventually disappear
# Competency
# Fix managed task icon color in dark mode
# Improve handling of offline and unauthorized errors
# Create frontend UI components for Teams connection management
# Enable auto deploy of Kosui to NPM
# Move cargo config to root to appease vscode
# Bump the cargo-deps group across 1 directory with 2 updates
# Add unattended upgrades to the setup script
# Make progress icon hoverable
# Add Badge component and Box base component to Kosui
# If task name is empty, show a "Click here to edit" prompt
# Upgrade bits-ui
# Add Bindable utility class for having bindable fields in Svelte contexts
# Gracefully shutdown github pollers
# Correct isManagedTask condition in BE
# Remove newCompContext methods in favor of explicit setCompContext(new CompContext())
# Configure environment variables in frontend based on environment
# Remove post-status change reordering
# koso-1013: Improve look and feel of the action item tooltip
# koso-971: Display remaining estimate for rollup tasks
# Show unauthorized dialog on inbox2 page
# Bump the github-actions-deps group with 5 updates
# Set version on sqlx-cli
# Directly configure the rust toolchain for CI
# Remove old Input component and use Kosui
# Prototype a task detail view
# Add MIT license
# Update dependency @sveltejs/kit to v2.20.6 [SECURITY]
# Add a "move to" tab in the link panel
# Check GitHub branch names for koso task refs
# Ensure that collaborators can add tasks without conflict
# Implement workflow: block on -> new task -> assign to someone else
# Remove slide dialog animations
# Migrate search for tasks component to Kosui
# Add child shortcut (shift+option+enter)
# Use Svelte context to pass toggle state around
# koso-913: All navigation buttons now allow copy link via href but uses goto on click
# Show an offline indicator and automatically reconnect when back online
# koso-857: In mobile mode, task context menu now appears on the mobile taskbar
# Changing a task from Not Started to In Progress doesn't react on the Inbox page
# Enable renovate and configure dependabot
# Convert build to Docker
# Update dependency vite to v6.2.5 [SECURITY]
# Use x-forwarded-for for logging and remove IP from who
# Starting to edit a row using the mouse should select that row
# Add support for Anthropic summaries of Koso iterations in project dashboard
# Filter out plugin configs for deleted projects
# Enable eslint in VS Code to provide lint errors in svelte files
# Remove the AI Rollup section
# Simplify the Github connection flow
# Command palette shows duplicate undent and indent commands
# Update install steps in the readme
# Improve plugins - github
# Make a component out of the Koso logo controllable via the theme
# Revert "Temporarily log headers (#952)"
# Use Lucide's svelte5 package
# Adjust icon colors for m3
# Validate Telegram messages using a Secret Token
# Implement task description markdown view popover on hover of the markdown view button
# Setup uptime checks
# Reimplement DagTable using HTML table
# Update Kosui buttons and links to match Material 3
# Expose navigation methods over rust graph
# Make markdown editor and task / node table independently scrollable
# Auto resolve tasks when PRs get merged
# Implement ability to set estimation in the task table of the inbox page
# Rename TaskAction -> TaskStatus
# Fix debug print of KosoEvent when deleting a YText field
# Modify link/search panels to sort by status
# Make inbox2 selection and navigation work with filtering
# koso-970: Add deadline and estimate to the frontend
# Create Teams OAuth client registration and app manifest configuration
# Speed up playwright tests
# Remove / rename Add Root
# Add videos to the landing page
# Update all dependencies
# Get rid of ghost and show drop target as a thick line
# Update API documentation for Teams endpoints
# Bump teloxide to 0.14
# Export backend logs to gcp or somewhere else
# Add a command to organize tasks in the current scope (move done to bottom, in progress to top)
# Avoid spawning a background task in GH webhook
# Modifying rust code triggers the dependencies docker layer to rebuild
# Fix shortcut throwing error for unmapped keys
# Reduce tooltip complexity to make them less annoying
# Add action / context menu to tasks
# initial commit and prop declaration
# Rewrite conflicting task numbers
# Command palette (cmd+p)
# Put sharing feature behind premium flag
# koso-833: Fix hard to click expand / collapse button
# Plugin to read tasks out of GitHub (checkout Tsugi for reference)
# Collapsing a node sometimes causes another node to expand
# Add Teams bot commands handling (like /token command)
# Add error and error_description to ErrorResponse
# Implement Poller
# navbar.svelte
# Fix test lint
# Implement a Koso MCP server
# Add working onSelect to Kosui menu
# Fix dialog box not triggering onSelect when clicking outside
# Order inbox tasks by priority
# Ignore remote transactions
# Propagate panics from spawned tasks
# Filter visible tasks in inbox2
# Compaction
# Show link + on drag immediately when option is pressed
# bug: insert child should start editing the task name
# Split dialogs into Dialoguer provider and Dialog component
# Try a different environment variable name for publishing
# Add a "copy git commit message" action for tasks
# Consolidate circular progress into one component and move to Kosui
# Optimize queries for config-by-installation by creating an index
# Integration tests
# Update dependency vitest to v1.6.1 [SECURITY] - autoclosed
# Closing the Link panel clears the filter text
# Update telegram notifier to use webhooks and remove teloxide
# Make a global Commander that you can register actions with anywhere
# Sharing a project with a user should not show all user's of Koso
# Update all dependencies
# Rename plain-tooltip to just tooltip
# Refactor github merge functions
# Refactor Menu, Command, and Autocomplete to look more similar
# Simplify the default stylings of Gotos, Buttons, and Fabs
# Fix staggered spacing when task name wraps
# Add deadlines / due dates for use in iteration risk assessment
# Fix tailwind intellisense of @apply in app.css
# Remove deadline column, remove haptics from long press, set tooltip duration to 500ms
# Do a demo
# Move inbox under project slug route
# Bump the npm-deps group across 1 directory with 12 updates
# Deflake playwright tests
# koso-854: Add a click flag to show Tooltip on click and delete TooltipTrigger
# Implement Awareness in the backend
# Move things into the relevant context
# Fix Inbox2 row selection and keyboard navigation
# Update all dependencies
# Bump yrs from 0.23.1 to 0.23.2 in the cargo-deps group across 1 directory
# Grant points on blocking of task
# Upgrade to Rust 1.85 and Rust 2024
# Treat eslint warnings as errors
# Add handler for keydown events when Popover is open (onKeydownWhileOpen)
# All navigation buttons should allow copy link via href but should prefer goto
# Add project debug page
# Migrates Label off of bits-ui
# fix(deps): update all dependencies
# Tweak versions in package.json
# Implement attention (indicate which tasks other users have selected)
# Toggle markdown editor back to view mode if task doesn't have any details
# Root
# Bump node to v24
# Factor out observer creation
# Introduce Kosui common folder and centralize Divider and Header
# Show a tag for all parents in the inbox
# Fix badge import in navbar
# Put a license on it
# Prune stale containers/images
# When adding a new task, start editing title by default
# Update all dependencies
# Add Kosui to the Workspace
# koso-869: Fix non-reactive task status
# Replace shadcn status menu with Kosui implementation
# Fix modal and popover behaviors wrt clicks and keyboard interactions
# Bump the cargo-deps group across 1 directory with 2 updates
# koso-902: Fix update hangs by untracking toasts
# Video of a plan being made in Koso
# option-move rows end up hidden under toolbar
# Video of multiple people planning in Koso
# Add a few more checks
# Fix node path
# Bump the docker-deps group with 2 updates
# Investigate performance scrolling / expanding / collapsing when there are many tasks
# Enable strict mode
# Bump the rust toolchain to 1.88.0 and address lints
# Tweak Link component so that it doesn't wrap when placed in body text
# Detect when running in standalone mode and adjust UI so that action bar is taller
# Lock file maintenance
# Navigate directly to a task from the inbox
# Update all dependencies
# Key all the svelte eaches and enable linter
# Bump the npm-deps group across 2 directories with 4 updates
# Whether or not a task has markdown should appear as a small icon at the beginning of the task in mobile mode
# Bump the npm-deps group across 1 directory with 6 updates
# After doing some action on a row, refocus the row
# Tweak log configuration
# Send notifications when a task is assigned to you by someone else
# Migrate from shadcn Alert to kosui
# Adjust margins to look more consistent with menubar
# Bump vite from 6.2.5 to 6.2.6 in /frontend in the npm_and_yarn group across 1 directory
# Update all dependencies
# Lock file maintenance
# Add swipe gestures for mobile: left = delete, right = done
# Add unit tests for YTaskProxy
# Import and export a project
# Adjust default environment variables
# Avoid waiting for slow clients to respond
# Standardize icon buttons
# Migrate to pnpm, bump deps, etc
# Migrate link panel component to Kosui
# Setup subscription billing
# Only show the Markdown view icon when markdown content exists
# Scroll if newly created task is out of the view port
# Add support for mapping certain repositories to certain projects
# Implement a task priority field
# Make sure teloxide always shuts down
# Remove unused shadcn-svelte (accordion, alert-dialog, button)
# Enable checks, lints, unit, and e2e tests
# koso-932: Use hamburger menu to navigate around storybook and hide when no items
# Set CI concurrency and on
# Add Organize Tasks action
# Don't new-up the telegram bot on every notify
# Omit the leading root slug from node ids in the inbox
# Implement Debug trait for project
# Update all dependencies
# Remove the CSS that was produced by shadcn-svelte
# Update dependency vite to v6.3.4 [SECURITY]
# Add invite only mode, I.e, cannot register until invited
# Migrate Kosui subfolder to separate package
# Remove github repo deploy key from server
# Executive view to show project progress, project risk status, and highlight critical paths
# After a task is deleted, the next task should be selected; or previous if no next
# Refactor project-share-modal to use Kosui
# Dragging a node towards the edge of a window should scroll
# circular-progress
# Group all dependabot updates together
# Common components
# Refactor koso and socket to not need onMount or onDestroy
# Menus (e.g. command, link) flash back to default content on close
# Add a category field to the command palette
# Link panel should be centered
# Factor out TypingBuffer
# Add several tests
# Adds skeleton component and updates branding
# Fix more imports trying to fix HMR
# Add rich flag to Tooltip to allow them to be invertible (dark on light / light on dark)
# Handle plugin tasks in the frontend
# Show Unassigned Ready tasks in the Inbox when there are no Actionable tasks
# koso-895: Fix task deep links
# Show toast when task disappears from inbox (juggled, done)
# Standardize formatting of notifications on Markdown
# PR for integration testing. Do not close
# Start with all nodes collapsed
# Introduce new TaskTable and TaskRow components for the reimagined inbox
# Add support for notifications in Slack
# Check for keys after blocking on a concurrent load
# Try unifying versions to make downcast work
# Add a new 'input' to dialoguer to allow inputs of various types
# Shortcuts should have a short name and a long name
# Migrate stores to Svelte $state rune
# Migrate Kosui from the Koso repo
# Implement a REST endpoint for points
# koso-902: Stop using deprecated stores
# Show first-time message when project has no tasks (e.g. Click here to create your first task!)
# Delete the perf page
# Convert from timestamp to timestamptz
# Cleanup a few development logs
# Setup backup and have a story for restore
# Add vite config support to enable linking Kosui
# Contextify Auth
# Update all dependencies
# Optimize retrieval from github when multiple projects integrate with the same installation
# Introduce dark mode
# controlled and delegated
# Adds textarea component to UI library
# Bugs
# Prototype notifications
# Text field should not have the same background as the task
# Validate docker image before deploy

# %%
async def get_embedding(data): 
    response = await client.embeddings.create(model="text-embedding-3-small", input=data, encoding_format="float")
    return response.data[0].embedding

# %%
await get_embedding("Koso will be revolutionary!")
# Out:
# [-0.00038371555,
#  0.0060764994,
#  -0.029341973,
#  0.041443132,
#  -0.03243762,
#  -0.018781234,
#  -0.0013173154,
#  0.021047423,
#  0.00850932,
#  -0.039251,
#  0.008568567,
#  -0.047575176,
#  -0.023298802,
#  0.015670776,
#  0.04484982,
#  -0.026838796,
#  -0.07690234,
#  -0.01605588,
#  0.017922156,
#  0.056017842,
#  -0.03477787,
#  0.010531117,
#  0.017374123,
#  -0.021373281,
#  0.03803644,
#  -0.019062655,
#  -0.028971681,
#  0.0003594151,
#  0.028008921,
#  -0.02520951,
#  0.03723661,
#  -0.024631854,
#  -0.033622555,
#  -0.05755826,
#  -0.040524807,
#  -0.028053356,
#  -0.027164655,
#  0.057321273,
#  -0.012056722,
#  0.01518199,
#  -0.016011445,
#  -0.05975039,
#  0.016263245,
#  0.060135495,
#  0.05607709,
#  -0.030215865,
#  -0.03486674,
#  -0.030837955,
#  -0.017951779,
#  0.026542563,
#  0.028631013,
#  0.022410098,
#  0.012938018,
#  -0.00048462025,
#  -0.019951357,
#  -0.013597139,
#  -0.031785905,
#  0.026527751,
#  0.007827982,
#  0.048967473,
#  0.028927246,
#  -0.071214646,
#  0.033296697,
#  -0.017255628,
#  -0.03350406,
#  -0.049648814,
#  0.0053803492,
#  -0.005872838,
#  0.017640732,
#  -0.01675203,
#  -0.02415788,
#  0.02049939,
#  -0.02180282,
#  0.01666316,
#  -0.0048397225,
#  -0.036140542,
#  0.031697035,
#  0.042509574,
#  0.0028494005,
#  -0.013989649,
#  -0.06659339,
#  0.028734695,
#  -0.026394445,
#  -0.04484982,
#  -0.022202736,
#  0.0010266359,
#  -0.018721987,
#  0.00884999,
#  -0.035459206,
#  0.039487988,
#  0.00993865,
#  0.02406901,
#  0.025846412,
#  -0.007020745,
#  0.022276795,
#  0.00090814225,
#  -0.026823986,
#  -0.014493247,
#  -0.027312772,
#  0.008561161,
#  -0.024691101,
#  0.029934442,
#  0.019892111,
#  0.050448645,
#  0.0036992216,
#  -0.038006816,
#  -0.008983295,
#  -0.013404587,
#  0.044286977,
#  0.021788009,
#  -0.029667832,
#  -0.008561161,
#  -0.004517568,
#  0.008768525,
#  0.026720304,
#  0.008842584,
#  0.0034066907,
#  -0.028423648,
#  -0.00881296,
#  0.029978877,
#  0.035873935,
#  0.018040648,
#  0.029060552,
#  0.00039204714,
#  -0.007024448,
#  -0.004510162,
#  0.010138608,
#  -0.02783118,
#  0.0056136334,
#  -0.013441616,
#  -0.016559478,
#  -0.014670987,
#  0.01286396,
#  -0.029016117,
#  0.02242491,
#  0.049559943,
#  -0.0064912266,
#  0.020025415,
#  0.008835178,
#  -0.013641574,
#  -0.016781654,
#  -0.028942058,
#  -0.028749507,
#  -0.032644983,
#  -0.01935889,
#  -0.012204839,
#  0.044583213,
#  -0.01413036,
#  0.024380054,
#  0.014048896,
#  -0.0068504103,
#  -0.0046841996,
#  -0.0060542817,
#  -0.03782908,
#  0.013152788,
#  -0.0471012,
#  -0.012552914,
#  0.043398276,
#  -0.010931034,
#  -0.0073095732,
#  0.02399495,
#  0.0035862825,
#  -0.019255208,
#  -0.0030401011,
#  -0.023432106,
#  0.0043694507,
#  -0.0028864297,
#  -0.016233621,
#  0.022469345,
#  -0.01901822,
#  -0.043309405,
#  -0.027016537,
#  -0.008879613,
#  -0.024394866,
#  -0.033385567,
#  -0.007102209,
#  -0.004895266,
#  -0.06576394,
#  -0.051396593,
#  -0.011878982,
#  -0.03575544,
#  0.002854955,
#  -0.011019903,
#  -0.03374105,
#  0.008353798,
#  0.0034826004,
#  0.008650032,
#  -0.020514201,
#  0.030141806,
#  0.0053544287,
#  -0.028231097,
#  -0.03305971,
#  0.017255628,
#  -0.008094593,
#  -0.013308311,
#  -0.028038545,
#  0.03782908,
#  -0.00022229119,
#  -0.003969535,
#  -0.042657692,
#  0.023224743,
#  -0.022750769,
#  -0.04055443,
#  -0.012530697,
#  0.0154782245,
#  0.015285673,
#  -0.009064759,
#  -0.027460888,
#  0.009131412,
#  0.006465306,
#  ...]

# %%
async def process_row(row, db, semaphore=asyncio.Semaphore(1)):
    async with semaphore:
        embedding = await get_embedding(row["name"])
        df = pd.DataFrame(
            [
                {
                    "id": row["id"],
                    "name": row["name"],
                    "embedding": json.dumps(embedding),
                }
            ]
        ).set_index('id')
        df.to_sql('embeddings',db, if_exists='append')
        return df

# %%
def get_processed_row_ids(db):
    try: 
        return {row[0] for row in db.execute('Select id from embeddings').fetchall()}
    except sqlite3.OperationalError as e: 
        print(f"Skipping delta due to error getting previously processed Id's: {3}")
    return set()

# %%
semaphore = asyncio.Semaphore(20)

db_file = 'koso-tasks-embeddings.sqlite'
db = sqlite3.connect(db_file, autocommit=True)

processed_ids = get_processed_row_ids(db)
filtered_tasks = [task for task in list(tasks.values()) if task['id'] not in processed_ids]

coros = []

for task in filtered_tasks: 
    coros.append(process_row(task, db, semaphore))
await tqdm_asyncio.gather(*coros)
# Out:
# Skipping delta due to error getting previously processed Id's: 3
# 100%|██████████| 1180/1180 [02:14<00:00,  8.80it/s]
# [                                                                                   name  \
#  id
#  5da056ad-bc67-42be-9488-e5e2eb93f71c  Update README with once a day / after every pu...
#
#                                                                                embedding
#  id
#  5da056ad-bc67-42be-9488-e5e2eb93f71c  [-0.017504742, -0.0052580032, 0.031297952, -0....  ,
#                                                name  \
#  id
#  c7ac6432-16f6-45a0-bf8d-11701c3c312f  Configure CI
#
#                                                                                embedding
#  id
#  c7ac6432-16f6-45a0-bf8d-11701c3c312f  [0.00743187, -0.009410439, 0.026777105, -0.025...  ,
#                                                                       name  \
#  id
#  ZR-1iPe6SWaYYEFbEtKnrg  Update dependency svelte to v4.2.19 [SECURITY]...
#
#                                                                  embedding
#  id
#  ZR-1iPe6SWaYYEFbEtKnrg  [-0.03172204, 0.017883565, 0.026026975, 0.0015...  ,
#                                                                   name  \
#  id
#  74b0c122-e13b-4718-89d6-7b34c9113ede  Add support for archiving tasks
#
#                                                                                embedding
#  id
#  74b0c122-e13b-4718-89d6-7b34c9113ede  [-0.019897953, 0.012595269, 0.033244472, -0.03...  ,
#                                          name  \
#  id
#  P526aJThQA2RNN9oPof7Sw  Fixup seats verbiage
#
#                                                                  embedding
#  id
#  P526aJThQA2RNN9oPof7Sw  [-0.043372512, 0.0013462672, 0.023259604, -0.0...  ,
#                                                                       name  \
#  id
#  doO8ZK7iSEmduTNDKsn-qA  Add more logging when processing anthropic req...
#
#                                                                  embedding
#  id
#  doO8ZK7iSEmduTNDKsn-qA  [-0.010325332, 0.032700557, 0.047025394, -0.03...  ,
#                                           name  \
#  id
#  S6QEkvq5Q-ifbdzHOsgp9w  Update dependabot.yml
#
#                                                                  embedding
#  id
#  S6QEkvq5Q-ifbdzHOsgp9w  [0.011632474, -0.00253643, 0.05071483, -0.0178...  ,
#                                                                                     name  \
#  id
#  be0f71db-ef88-499c-af80-63c2914a6d01  Refactor LinkPanel and TaskStatus to take Task...
#
#                                                                                embedding
#  id
#  be0f71db-ef88-499c-af80-63c2914a6d01  [-0.05590241, -0.007301495, -0.06788768, 0.033...  ,
#                                                  name  \
#  id
#  b3c15ca9-9b86-489c-94a0-da2156ac80ee  Open the doors
#
#                                                                                embedding
#  id
#  b3c15ca9-9b86-489c-94a0-da2156ac80ee  [0.01590793, 0.026526695, 0.010651115, 0.00399...  ,
#                                                       name  \
#  id
#  799abfcd-f39a-4440-833e-7a218d7cd120  Navbar Improvements
#
#                                                                                embedding
#  id
#  799abfcd-f39a-4440-833e-7a218d7cd120  [-0.055344593, 0.020545846, 0.0048864107, 0.01...  ,
#                                                                        name  \
#  id
#  c4830a3c-3909-4807-a6a8-fb46753ec3e0  Suppress noisy chrome workspace logs
#
#                                                                                embedding
#  id
#  c4830a3c-3909-4807-a6a8-fb46753ec3e0  [0.03247958, 0.027492234, 0.025706133, -0.0330...  ,
#                                                                                     name  \
#  id
#  23bb1e72-127b-47e4-9822-59f5731df7b4  Plugin to import review of GitHub PRs as a kos...
#
#                                                                                embedding
#  id
#  23bb1e72-127b-47e4-9822-59f5731df7b4  [-0.06415215, 0.06699521, 0.0015418987, -0.006...  ,
#                                                                  name  \
#  id
#  17912f5c-78e6-4cc2-98d4-129c7fafd15f  Disable Delete action in inbox
#
#                                                                                embedding
#  id
#  17912f5c-78e6-4cc2-98d4-129c7fafd15f  [0.018573066, 0.028036198, -0.03122711, 0.0200...  ,
#                                                              name  \
#  id
#  f4f98180-d216-4889-aa4c-ba1c4bf6802d  Bump mode-watcher to 1.0.0
#
#                                                                                embedding
#  id
#  f4f98180-d216-4889-aa4c-ba1c4bf6802d  [0.0012417358, 0.032069698, -0.010747348, -0.0...  ,
#                                                                                     name  \
#  id
#  f67714fc-8763-4af7-8887-7b0006802295  Move telegram notifications out of deploy.sh i...
#
#                                                                                embedding
#  id
#  f67714fc-8763-4af7-8887-7b0006802295  [0.01721992, 0.007812741, -0.03681236, 0.02196...  ,
#                                                                                     name  \
#  id
#  80d3014e-607e-4379-8a37-6c77e44c405b  Cmd+Shift+Option+Enter should create a new chi...
#
#                                                                                embedding
#  id
#  80d3014e-607e-4379-8a37-6c77e44c405b  [0.02327163, 0.013225802, 0.016357595, 0.02775...  ,
#                                                                    name  \
#  id
#  2e7aa496-78d1-4df5-8fcd-31de97ae2a78  Markdown editor should wrap text
#
#                                                                                embedding
#  id
#  2e7aa496-78d1-4df5-8fcd-31de97ae2a78  [-0.042410932, 0.031908415, 0.006059659, 0.002...  ,
#                                                                    name  \
#  id
#  ada31236-ca88-4cdf-8c48-64f7d8f5bc2b  Improve socket shutdown handling
#
#                                                                                embedding
#  id
#  ada31236-ca88-4cdf-8c48-64f7d8f5bc2b  [-0.012713685, -0.0010152815, -0.0067845094, 0...  ,
#                                                                         name  \
#  id
#  7e353788-7924-425f-8d61-2268a0413ec4  Try setting the exact install version
#
#                                                                                embedding
#  id
#  7e353788-7924-425f-8d61-2268a0413ec4  [-0.047880553, -0.0365614, 0.03552514, -0.0523...  ,
#                                                                name  \
#  id
#  fbadb5ff-f176-4b62-bd8f-1a051b7a1e1a  Fix dark mode for the editor
#
#                                                                                embedding
#  id
#  fbadb5ff-f176-4b62-bd8f-1a051b7a1e1a  [-0.04371782, -0.0017671423, -0.019899307, -0....  ,
#                                                             name  \
#  id
#  f52852ce-b556-47ab-8e24-0f3a5dc61360  Fix several lint warnings
#
#                                                                                embedding
#  id
#  f52852ce-b556-47ab-8e24-0f3a5dc61360  [-0.030934893, -0.0014417468, 0.0099493675, -0...  ,
#                                                                                     name  \
#  id
#  62666e73-36bb-498c-bcbb-59d151bc4fc8  Create a test that ensures various widths of b...
#
#                                                                                embedding
#  id
#  62666e73-36bb-498c-bcbb-59d151bc4fc8  [-0.011164191, 0.014057257, 0.034448806, 0.011...  ,
#                                                                                     name  \
#  id
#  5e6bffc9-b964-4cc0-8dba-af32bac279b6  Nodes should only expand after a delay when dr...
#
#                                                                                embedding
#  id
#  5e6bffc9-b964-4cc0-8dba-af32bac279b6  [0.01490212, 0.015160064, 0.03329821, 0.007673...  ,
#                                                                         name  \
#  id
#  4071b81a-b9f2-4802-b288-09112f44d195  Handle juggled tasks in toggle status
#
#                                                                                embedding
#  id
#  4071b81a-b9f2-4802-b288-09112f44d195  [-0.025224825, 0.02571622, -0.00095300406, 0.0...  ,
#                                                       name  \
#  id
#  fc1c98d5-dbd0-4303-9074-b169b231d282  Fix task deep links
#
#                                                                                embedding
#  id
#  fc1c98d5-dbd0-4303-9074-b169b231d282  [-0.061388444, 0.011218367, 0.0130045125, -0.0...  ,
#                                                                                     name  \
#  id
#  22eab22d-68f6-4936-a1cb-77916323c21f  Simplify render delegation by using useRef cal...
#
#                                                                                embedding
#  id
#  22eab22d-68f6-4936-a1cb-77916323c21f  [-0.032740712, -0.0037164972, -0.031911533, 0....  ,
#                                                                    name  \
#  id
#  5021555b-1b8f-4962-817c-8a2c9b780db1  Adopt tailwind-variants in Kosui
#
#                                                                                embedding
#  id
#  5021555b-1b8f-4962-817c-8a2c9b780db1  [-0.007588928, 0.0069167237, 0.058566246, 0.00...  ,
#                                                                               name  \
#  id
#  ee7f3539-8e7f-4854-ad29-d5b0fe313f43  Refactor status, kind and progress handling
#
#                                                                                embedding
#  id
#  ee7f3539-8e7f-4854-ad29-d5b0fe313f43  [-0.00095417094, 0.036551017, -0.011519699, 0....  ,
#                                                                      name  \
#  id
#  2b9f85cd-9aee-4fb4-b556-981f5f187ab1  Display badges for premium members
#
#                                                                                embedding
#  id
#  2b9f85cd-9aee-4fb4-b556-981f5f187ab1  [-0.014036051, -0.033267617, -0.022563769, 0.0...  ,
#                                                              name  \
#  id
#  020f9225-e122-4550-9cb9-5705306356fe  project-share-modal.svelte
#
#                                                                                embedding
#  id
#  020f9225-e122-4550-9cb9-5705306356fe  [-0.01036537, -0.006884157, -0.023711719, 0.00...  ,
#                                                          name  \
#  id
#  2b1a04e1-fe97-400b-b5a1-dfa95eff8499  Downgrade to rust 1.86
#
#                                                                                embedding
#  id
#  2b1a04e1-fe97-400b-b5a1-dfa95eff8499  [-0.019451188, -0.008729957, 0.012468541, -0.0...  ,
#                                                              name  \
#  id
#  68d430da-ac8d-4129-bacc-bc785ed50324  Break circular import deps
#
#                                                                                embedding
#  id
#  68d430da-ac8d-4129-bacc-bc785ed50324  [0.00029587094, -0.013548105, 0.074191324, -0....  ,
#                                                                                     name  \
#  id
#  b547372d-a894-4e42-9c0b-6b696258707d  Uses enum style constants for ActionIDs instea...
#
#                                                                                embedding
#  id
#  b547372d-a894-4e42-9c0b-6b696258707d  [0.00067238434, -0.034605917, -0.0038729338, -...  ,
#                                                                                     name  \
#  id
#  e4d73ce7-2ba7-4c96-9ba5-ddbf73bdd7b6  Bump the npm-deps group across 1 directory wit...
#
#                                                                                embedding
#  id
#  e4d73ce7-2ba7-4c96-9ba5-ddbf73bdd7b6  [-0.05135937, -0.022729145, 0.057110418, -0.01...  ,
#                                                                         name  \
#  id
#  cf4b9e4a-664a-4fb6-b280-1599b2b40a11  Handle selection when tasks disappear
#
#                                                                                embedding
#  id
#  cf4b9e4a-664a-4fb6-b280-1599b2b40a11  [-0.0055015963, 0.012661501, 0.024226952, -0.0...  ,
#                                                                    name  \
#  id
#  99b6ad1d-f574-46d4-bb8a-c6abfa26fb7f  Make action item tooltip clearer
#
#                                                                                embedding
#  id
#  99b6ad1d-f574-46d4-bb8a-c6abfa26fb7f  [-0.046017148, -0.002389322, -0.047407858, 0.0...  ,
#                                                   name  \
#  id
#  xNzZ5Zq8TWiTIpsM8PYAbQ  aAdd note about remote server
#
#                                                                  embedding
#  id
#  xNzZ5Zq8TWiTIpsM8PYAbQ  [-0.018838216, -0.0095124375, 0.0137625225, -0...  ,
#                                                                                     name  \
#  id
#  5f2cf3a7-8e85-499c-9a29-986297b2bd21  Add commands to cycle between the nodes of a task
#
#                                                                                embedding
#  id
#  5f2cf3a7-8e85-499c-9a29-986297b2bd21  [-0.026372759, 0.014420192, 0.017787473, -0.04...  ,
#                                                  name  \
#  id
#  Ra7Fd4NASmSAIEytXxu5HQ  Experiment fixing Svelte bug
#
#                                                                  embedding
#  id
#  Ra7Fd4NASmSAIEytXxu5HQ  [-0.060723152, -0.010140438, 0.0062388335, -0....  ,
#                                             name  \
#  id
#  872fdc06-0cac-47be-8fc4-dc9f1d5bc04e  Usability
#
#                                                                                embedding
#  id
#  872fdc06-0cac-47be-8fc4-dc9f1d5bc04e  [-0.009939973, 0.00911825, -0.017789597, 0.039...  ,
#                                                                                     name  \
#  id
#  bf4ee114-37b7-4284-b4be-851f98112475  koso-741: Always show the markdown viewer / ed...
#
#                                                                                embedding
#  id
#  bf4ee114-37b7-4284-b4be-851f98112475  [-0.012647243, 0.042702887, 0.021968381, 0.000...  ,
#                                                                       name  \
#  id
#  7atAzPrHTVKhcM37_Dxc1g  Migrate Input, Textarea, and Alert components ...
#
#                                                                  embedding
#  id
#  7atAzPrHTVKhcM37_Dxc1g  [-0.044084277, 0.03426719, 0.0236695, 0.017186...  ,
#                                                                                     name  \
#  id
#  680bebd1-6d6d-41b0-84a3-5367af2e0c29  Add all Input variants and Scale parameter to ...
#
#                                                                                embedding
#  id
#  680bebd1-6d6d-41b0-84a3-5367af2e0c29  [-0.034616403, 0.024576368, -0.002085287, -0.0...  ,
#                                                                  name  \
#  id
#  950f19c7-f25a-4bf3-b813-d3991f31ac9d  Add support for floating tasks
#
#                                                                                embedding
#  id
#  950f19c7-f25a-4bf3-b813-d3991f31ac9d  [-0.03042273, 0.0038785539, 0.05236564, -0.020...  ,
#                                          name  \
#  id
#  XBiBI403S6SIQFf1VlDcsQ  Try fixing down cast
#
#                                                                  embedding
#  id
#  XBiBI403S6SIQFf1VlDcsQ  [-0.010070335, 0.04538785, 0.01997546, 0.02128...  ,
#                                                                           name  \
#  id
#  56c06f7f-20d3-45b9-b1b7-6b0413d8d01c  Add integration tests for collaboration
#
#                                                                                embedding
#  id
#  56c06f7f-20d3-45b9-b1b7-6b0413d8d01c  [-0.036240973, 0.001306089, 0.066595346, -0.04...  ,
#                                                                                     name  \
#  id
#  ca9d525d-b86d-43c4-aa3c-360a3cc3ae23  koso-853: Add a `rich` flag to Tooltip compone...
#
#                                                                                embedding
#  id
#  ca9d525d-b86d-43c4-aa3c-360a3cc3ae23  [-0.03932832, 0.018852508, -0.01077901, 0.0167...  ,
#                                                                                     name  \
#  id
#  c6fea87c-9556-41b1-833c-9da2d9418e33  Implement client side warnings when schema is off
#
#                                                                                embedding
#  id
#  c6fea87c-9556-41b1-833c-9da2d9418e33  [-0.013626794, 0.05033837, 0.057998557, 0.0208...  ,
#                                                                          name  \
#  id
#  6a11b95f-0e89-4c9e-8fcf-9594621aa2e3  Add support for GitHub reference links
#
#                                                                                embedding
#  id
#  6a11b95f-0e89-4c9e-8fcf-9594621aa2e3  [-0.022437336, -0.03192576, 0.00014534965, 0.0...  ,
#                                                                                     name  \
#  id
#  a3827817-a13a-41f8-b191-bbee2bd79636  Add action to copy task permalink to the clipb...
#
#                                                                                embedding
#  id
#  a3827817-a13a-41f8-b191-bbee2bd79636  [0.0045182654, -0.010101241, -0.025207164, -0....  ,
#                                                          name  \
#  id
#  b8903fef-9695-431a-bf15-44f577643ad9  Promote Chips to Kosui
#
#                                                                                embedding
#  id
#  b8903fef-9695-431a-bf15-44f577643ad9  [0.017962769, -0.024674783, -0.053045608, 0.00...  ,
#                                                                                     name  \
#  id
#  0f97e324-02c5-4e39-88e8-01fbfb989899  Bump openssl from 0.10.68 to 0.10.70 in the ca...
#
#                                                                                embedding
#  id
#  0f97e324-02c5-4e39-88e8-01fbfb989899  [0.003166045, -0.029693665, 0.08294079, 0.0132...  ,
#                                                                                     name  \
#  id
#  0a9659ae-91be-4de5-b69e-58182133a0cf  Add a category field to help organize the comm...
#
#                                                                                embedding
#  id
#  0a9659ae-91be-4de5-b69e-58182133a0cf  [-0.03984278, -0.02231652, -0.03419078, -0.012...  ,
#                                           name  \
#  id
#  84173e80-db91-4d5b-8e79-b9ff9af5d5a7  Archive
#
#                                                                                embedding
#  id
#  84173e80-db91-4d5b-8e79-b9ff9af5d5a7  [0.005062292, 0.006633953, -0.024641398, -0.00...  ,
#                                                                                     name  \
#  id
#  ea6146d6-0816-46b1-bd16-0035b2ed467a  Update secondary colors to provide a nice cont...
#
#                                                                                embedding
#  id
#  ea6146d6-0816-46b1-bd16-0035b2ed467a  [-0.024571862, -0.04478169, -0.0067200856, 0.0...  ,
#                                                           name  \
#  id
#  07ed5695-87c1-4bb4-96ef-cde12373d02c  Update all dependencies
#
#                                                                                embedding
#  id
#  07ed5695-87c1-4bb4-96ef-cde12373d02c  [-0.042679295, -0.013746619, 0.050524224, -0.0...  ,
#                                                                           name  \
#  id
#  ce738db1-b5e0-430a-99f2-fa39c59611a0  Use project context in task detail page
#
#                                                                                embedding
#  id
#  ce738db1-b5e0-430a-99f2-fa39c59611a0  [-0.026359119, -0.006088981, 0.01729588, 0.012...  ,
#                                                                                     name  \
#  id
#  c58448c3-69b1-4ee0-af5e-0bfdfc961496  koso-910: Fix premium crown causing horizontal...
#
#                                                                                embedding
#  id
#  c58448c3-69b1-4ee0-af5e-0bfdfc961496  [0.008728968, -0.017399205, 0.056587793, 0.008...  ,
#                                                     name  \
#  id
#  cb0d11f0-f17c-4548-9b5d-30ab7603e1cc  stylable markdown
#
#                                                                                embedding
#  id
#  cb0d11f0-f17c-4548-9b5d-30ab7603e1cc  [0.0041542584, 0.0054564998, -0.03926097, -0.0...  ,
#                                                                 name  \
#  id
#  kT_heQ6-RmSub0IqdRWLCA  Create Teams app registration documentation
#
#                                                                  embedding
#  id
#  kT_heQ6-RmSub0IqdRWLCA  [0.006968254, 0.03112403, 0.024206178, -0.0169...  ,
#                                                                             name  \
#  id
#  2a6bbe3b-ee4a-40cb-ba4a-f96023ad6448  Bump the docker-deps group with 2 updates
#
#                                                                                embedding
#  id
#  2a6bbe3b-ee4a-40cb-ba4a-f96023ad6448  [-0.024676146, -0.0029885338, 0.06981163, -0.0...  ,
#                                                            name  \
#  id
#  bc93ab1f-170e-49eb-8006-bf683800655a  circular-progress-status
#
#                                                                                embedding
#  id
#  bc93ab1f-170e-49eb-8006-bf683800655a  [0.009598172, -0.012487944, 0.03871705, 0.0262...  ,
#                                                         name  \
#  id
#  c4833956-4f90-49e2-a77c-2d9054fc867b  Run clippy over tests
#
#                                                                                embedding
#  id
#  c4833956-4f90-49e2-a77c-2d9054fc867b  [-0.017421404, 0.0030715263, 0.04355351, -0.03...  ,
#                                                                    name  \
#  id
#  9440c7fa-0bd6-4312-baa0-21040a4d2e02  Add support for mermaid diagrams
#
#                                                                                embedding
#  id
#  9440c7fa-0bd6-4312-baa0-21040a4d2e02  [0.012518689, 0.013022619, 0.016947972, -0.014...  ,
#                                                                                     name  \
#  id
#  3e3d349d-9256-4ff3-a2f7-bda50ee68388  Refactor Kosui autocomplete component to use a...
#
#                                                                                embedding
#  id
#  3e3d349d-9256-4ff3-a2f7-bda50ee68388  [-0.063125536, -0.0009321992, -0.023375433, 0....  ,
#                                                           name  \
#  id
#  37d4df42-eb68-49b0-a253-b302146c2099  Update all dependencies
#
#                                                                                embedding
#  id
#  37d4df42-eb68-49b0-a253-b302146c2099  [-0.042644545, -0.013803113, 0.05051148, -0.03...  ,
#                                                                                     name  \
#  id
#  9f02d675-2a24-4502-bb61-287e60282767  Add uncontrolled flag to Menu to disable close...
#
#                                                                                embedding
#  id
#  9f02d675-2a24-4502-bb61-287e60282767  [-0.0035496633, 0.03229357, -0.04749617, 0.008...  ,
#                                                                      name  \
#  id
#  9b86a483-68e7-4ba8-80c4-9a137d6287a0  Make Navbar available on all pages
#
#                                                                                embedding
#  id
#  9b86a483-68e7-4ba8-80c4-9a137d6287a0  [-0.013101986, 0.051712263, -0.018737, 0.02476...  ,
#                                                       name  \
#  id
#  9db0d6f7-3d1d-4f11-a812-d5f5e78f9742  Svelte 5: Migration
#
#                                                                                embedding
#  id
#  9db0d6f7-3d1d-4f11-a812-d5f5e78f9742  [0.024582138, 0.044501085, 0.01125652, -0.0303...  ,
#                                                                                    name  \
#  id
#  04062d43-129e-4a7d-9825-e3b229d75df6  Implement render delegated version of Kosui menu
#
#                                                                                embedding
#  id
#  04062d43-129e-4a7d-9825-e3b229d75df6  [-0.033655856, 0.015539601, -0.022791415, -0.0...  ,
#                                                                     name  \
#  id
#  43f47b02-c394-4e87-a337-9bc9c0f4f8ea  Add our first UI interaction test
#
#                                                                                embedding
#  id
#  43f47b02-c394-4e87-a337-9bc9c0f4f8ea  [-0.03521296, 0.0048685125, 0.0066790576, -0.0...  ,
#                                                                                 name  \
#  id
#  179193c3-3967-407a-b75e-51053846feeb  Add experimental support for mermaid diagrams
#
#                                                                                embedding
#  id
#  179193c3-3967-407a-b75e-51053846feeb  [0.013265548, 0.027224902, 0.023617117, -0.002...  ,
#                                                             name  \
#  id
#  1d624f06-59b4-46ea-9423-afc08160373c  Write an integration test
#
#                                                                                embedding
#  id
#  1d624f06-59b4-46ea-9423-afc08160373c  [-0.003213736, -0.010195082, 0.04489391, -0.06...  ,
#                                                                    name  \
#  id
#  e69b6fcd-8d70-463f-b58d-66c1ac382454  Fix "Take me home" dialog escape
#
#                                                                                embedding
#  id
#  e69b6fcd-8d70-463f-b58d-66c1ac382454  [-0.04367201, 0.0010007535, 0.021334203, -5.31...  ,
#                                                                       name  \
#  id
#  Csgu2P8RQUSTF72CbiHDWA  Try a different environment variable name for ...
#
#                                                                  embedding
#  id
#  Csgu2P8RQUSTF72CbiHDWA  [0.0034072038, -0.04112336, 0.077508435, -0.00...  ,
#                                                                                     name  \
#  id
#  2c88e765-2cb9-4a18-b8f2-bb89e000b0be  By default, tasks that have children should sh...
#
#                                                                                embedding
#  id
#  2c88e765-2cb9-4a18-b8f2-bb89e000b0be  [0.014387653, 0.020913266, 0.01856549, 0.02853...  ,
#                                                           name  \
#  id
#  kyXMNEBxShWg8q1oiCHZgw  Correct multi-ecosystem-group pattern
#
#                                                                  embedding
#  id
#  kyXMNEBxShWg8q1oiCHZgw  [-0.0032212455, 0.031285744, 0.08588011, 0.020...  ,
#                                                          name  \
#  id
#  1050643b-2355-4eba-bc18-38219760918b  Update pnpm to v10.8.1
#
#                                                                                embedding
#  id
#  1050643b-2355-4eba-bc18-38219760918b  [-0.017354634, 0.0025530998, 0.025639392, -0.0...  ,
#                                                                 name  \
#  id
#  4e8c897d-e3cf-4409-a9fb-7e33b435f67a  Add type for awareness update
#
#                                                                                embedding
#  id
#  4e8c897d-e3cf-4409-a9fb-7e33b435f67a  [-0.03630698, 0.024630286, -0.05421432, -0.012...  ,
#                                                                       name  \
#  id
#  xLpT1hwnTyGTa-Kfnjh6cw  Fix static content links to work for unauthent...
#
#                                                                  embedding
#  id
#  xLpT1hwnTyGTa-Kfnjh6cw  [-0.045698963, 0.002053687, -0.018539472, -0.0...  ,
#                                                                                 name  \
#  id
#  76cd6bee-b952-489e-a93c-09f6c29268b3  Add a cool UI effect when a user earns points
#
#                                                                                embedding
#  id
#  76cd6bee-b952-489e-a93c-09f6c29268b3  [-0.018384648, -0.016952436, -0.06621228, 0.03...  ,
#                                                 name  \
#  id
#  VvuxPKbsRaihInfM4aQa_w  Add Teams integration tests
#
#                                                                  embedding
#  id
#  VvuxPKbsRaihInfM4aQa_w  [-0.030348502, -0.0031159036, 0.06659663, -0.0...  ,
#                                                                                name  \
#  id
#  e4be31ff-b56e-4b77-8423-d0d848dd77f4  Delete shadcn-svelte dropdown-menu component
#
#                                                                                embedding
#  id
#  e4be31ff-b56e-4b77-8423-d0d848dd77f4  [-0.043851193, -0.0033058259, 0.039539248, -0....  ,
#                                                                                     name  \
#  id
#  dae27b7f-8a3e-46f1-b26c-3397f616175a  Add task size estimate field that defaults to ...
#
#                                                                                embedding
#  id
#  dae27b7f-8a3e-46f1-b26c-3397f616175a  [-0.027114455, 0.011528502, 0.049272504, 0.002...  ,
#                                                                    name  \
#  id
#  ac2de6d4-1b19-4f55-81f4-b623125c7bb7  Stop using node in organizeTasks
#
#                                                                                embedding
#  id
#  ac2de6d4-1b19-4f55-81f4-b623125c7bb7  [-0.015852423, -0.0032543512, 0.033625554, -0....  ,
#                                                                                     name  \
#  id
#  02a0fd41-7e83-4aec-b5c5-8d8b533219ac  Rename Row -> DagRow to match TaskTable / TaskRow
#
#                                                                                embedding
#  id
#  02a0fd41-7e83-4aec-b5c5-8d8b533219ac  [-0.03463812, 0.020563882, -0.0024035706, -0.0...  ,
#                                                   name  \
#  id
#  d0a88c81-6ad9-44ff-9e2b-449de51a6af8  dag-table/table
#
#                                                                                embedding
#  id
#  d0a88c81-6ad9-44ff-9e2b-449de51a6af8  [-0.045557007, 0.02105088, 0.06625946, -0.0374...  ,
#                                                                 name  \
#  id
#  0a31a1bd-8de9-4384-86d8-828911325717  Use the success toast variant
#
#                                                                                embedding
#  id
#  0a31a1bd-8de9-4384-86d8-828911325717  [-0.016029276, -0.03158314, 0.020933932, -0.02...  ,
#                                                                            name  \
#  id
#  2ad876ae-81d8-4eb8-a0e9-f6c32982032f  Remove old images from github containers
#
#                                                                                embedding
#  id
#  2ad876ae-81d8-4eb8-a0e9-f6c32982032f  [0.006852929, 0.01235796, 0.030641334, -0.0202...  ,
#                                                                                name  \
#  id
#  fc99e208-3ba2-4b56-9aa3-53a0e9ba5afc  Split planning context tests from koso tests
#
#                                                                                embedding
#  id
#  fc99e208-3ba2-4b56-9aa3-53a0e9ba5afc  [-0.037199132, 0.010823636, 0.05767859, -0.049...  ,
#                                                                                     name  \
#  id
#  e2861e11-8587-4ddb-ad59-422dd9cf4b4a  Creating a new project errors on first load wi...
#
#                                                                                embedding
#  id
#  e2861e11-8587-4ddb-ad59-422dd9cf4b4a  [-0.022374695, -0.008869191, 0.026216945, -0.0...  ,
#                                                                               name  \
#  id
#  c1d2ca4d-2950-4035-981a-3867e51233f3  Move event handling to notifications module
#
#                                                                                embedding
#  id
#  c1d2ca4d-2950-4035-981a-3867e51233f3  [-0.012062026, 0.043225516, -0.015757404, 0.00...  ,
#                                                                                     name  \
#  id
#  4f119651-359d-471e-ba09-648d0f882c62  Tweak mobile toolbar to be open / close instea...
#
#                                                                                embedding
#  id
#  4f119651-359d-471e-ba09-648d0f882c62  [-0.027017485, 0.035692826, -0.035097945, 0.00...  ,
#                                                                                 name  \
#  id
#  8d6c0e82-5bef-49e3-a41e-3d5c94926022  Search should show tags associated with tasks
#
#                                                                                embedding
#  id
#  8d6c0e82-5bef-49e3-a41e-3d5c94926022  [-0.039014477, 0.0014870855, -0.02182246, -0.0...  ,
#                                                                                  name  \
#  id
#  13bb2b35-ddf4-4547-b86d-03441a6976e2  Sticky bar not so sticky on Chrome for Android
#
#                                                                                embedding
#  id
#  13bb2b35-ddf4-4547-b86d-03441a6976e2  [-0.005363598, -0.010560186, -0.034661047, -0....  ,
#                                                                             name  \
# ...
#  6263a81b-1146-41da-bb0b-c981326fadd5  [0.021199806, -0.011152255, -0.00074592215, -0...  ,
#                                                                     name  \
#  id
#  QncVVqENTZyhMYQbwEXMiA  Validate Telegram messages using a Secret Token
#
#                                                                  embedding
#  id
#  QncVVqENTZyhMYQbwEXMiA  [0.0018067723, -0.027404454, 0.0019902843, -0....  ,
#                                                                                     name  \
#  id
#  8983d777-3c1f-4200-8f3f-f25469a40ff3  Implement task description markdown view popov...
#
#                                                                                embedding
#  id
#  8983d777-3c1f-4200-8f3f-f25469a40ff3  [-0.035226315, 0.020414477, -0.017726572, 0.01...  ,
#                                                       name  \
#  id
#  070b83c4-6bb0-421d-b60e-2cec2175556e  Setup uptime checks
#
#                                                                                embedding
#  id
#  070b83c4-6bb0-421d-b60e-2cec2175556e  [-0.053625375, 0.0382173, 0.068901755, -0.0064...  ,
#                                                                         name  \
#  id
#  99db644b-9dec-4603-8167-703cca3f2652  Reimplement DagTable using HTML table
#
#                                                                                embedding
#  id
#  99db644b-9dec-4603-8167-703cca3f2652  [-0.049743507, -0.0037605884, 0.06354097, -0.0...  ,
#                                                                                     name  \
#  id
#  878153bf-8395-4dc8-ae5c-f77d7fb83106  Update Kosui buttons and links to match Materi...
#
#                                                                                embedding
#  id
#  878153bf-8395-4dc8-ae5c-f77d7fb83106  [-0.059426077, 0.003443715, -0.00381187, 0.006...  ,
#                                                                             name  \
#  id
#  518a17b1-ee73-460f-8084-e7079dcfa7c6  Expose navigation methods over rust graph
#
#                                                                                embedding
#  id
#  518a17b1-ee73-460f-8084-e7079dcfa7c6  [-0.021680733, 0.022032466, 0.033287875, -0.01...  ,
#                                                                                     name  \
#  id
#  cb36f6ba-1241-41fb-81d2-09aa9a27eaab  Make markdown editor and task / node table ind...
#
#                                                                                embedding
#  id
#  cb36f6ba-1241-41fb-81d2-09aa9a27eaab  [-0.025182206, 0.008698743, 0.026512822, -0.01...  ,
#                                                                          name  \
#  id
#  3ffcf5b2-32f0-44f4-8ccf-bad8116b50e3  Auto resolve tasks when PRs get merged
#
#                                                                                embedding
#  id
#  3ffcf5b2-32f0-44f4-8ccf-bad8116b50e3  [-0.027400568, 0.038458288, 0.06254924, -0.011...  ,
#                                                                                     name  \
#  id
#  764a0246-1e36-4f4e-8a57-026249004747  Implement ability to set estimation in the tas...
#
#                                                                                embedding
#  id
#  764a0246-1e36-4f4e-8a57-026249004747  [0.009107167, 0.01310685, 0.01916756, 0.034651...  ,
#                                                                   name  \
#  id
#  2afc8a10-7498-4bf9-b59f-b71268e989b4  Rename TaskAction -> TaskStatus
#
#                                                                                embedding
#  id
#  2afc8a10-7498-4bf9-b59f-b71268e989b4  [-0.03100221, 0.015627852, -0.0035584099, -0.0...  ,
#                                                                                     name  \
#  id
#  39f8e965-ba9c-49f2-8b62-92fa5990da46  Fix debug print of KosoEvent when deleting a Y...
#
#                                                                                embedding
#  id
#  39f8e965-ba9c-49f2-8b62-92fa5990da46  [-0.020546304, 0.060329136, -0.006188367, -0.0...  ,
#                                                                               name  \
#  id
#  76245b3f-f681-487e-ba2f-c2d346a78869  Modify link/search panels to sort by status
#
#                                                                                embedding
#  id
#  76245b3f-f681-487e-ba2f-c2d346a78869  [-0.06393473, -0.0013433998, -0.03901899, -0.0...  ,
#                                                                                     name  \
#  id
#  8c64d620-5a55-41fc-bc25-726f804d0f5a  Make inbox2 selection and navigation work with...
#
#                                                                                embedding
#  id
#  8c64d620-5a55-41fc-bc25-726f804d0f5a  [-0.007250588, -0.004272336, -0.0059565036, 0....  ,
#                                                                                     name  \
#  id
#  a5375518-8ab0-48c9-a5be-5d1dc55d5fbf  koso-970: Add deadline and estimate to the fro...
#
#                                                                                embedding
#  id
#  a5375518-8ab0-48c9-a5be-5d1dc55d5fbf  [-0.024855511, 0.023989271, 0.016598284, -0.03...  ,
#                                                                       name  \
#  id
#  QeS2P6qlSfGZkqeks_sLWQ  Create Teams OAuth client registration and app...
#
#                                                                  embedding
#  id
#  QeS2P6qlSfGZkqeks_sLWQ  [-0.012321616, 0.007971221, 0.03484639, -0.017...  ,
#                                                             name  \
#  id
#  8f46141e-f054-43f5-8e92-62888b320462  Speed up playwright tests
#
#                                                                                embedding
#  id
#  8f46141e-f054-43f5-8e92-62888b320462  [-0.031496745, -0.009858913, 0.013217128, -0.0...  ,
#                                                            name  \
#  id
#  85928de4-71b0-41cb-ba41-a1bf0935bdbd  Remove / rename Add Root
#
#                                                                                embedding
#  id
#  85928de4-71b0-41cb-ba41-a1bf0935bdbd  [-0.012903529, 0.024565216, 0.018110218, -0.01...  ,
#                                                                  name  \
#  id
#  dc1eb73e-9324-409a-b1b0-fe449087577b  Add videos to the landing page
#
#                                                                                embedding
#  id
#  dc1eb73e-9324-409a-b1b0-fe449087577b  [0.013658939, -0.002442612, -0.044323873, -0.0...  ,
#                                                           name  \
#  id
#  95806b07-e8e4-4b22-986b-e5743e2aad8c  Update all dependencies
#
#                                                                                embedding
#  id
#  95806b07-e8e4-4b22-986b-e5743e2aad8c  [-0.042679295, -0.013746619, 0.050524224, -0.0...  ,
#                                                                                     name  \
#  id
#  3c044062-9f9e-447b-a068-924e5e90b467  Get rid of ghost and show drop target as a thi...
#
#                                                                                embedding
#  id
#  3c044062-9f9e-447b-a068-924e5e90b467  [-0.013629344, 0.0203352, 0.0235181, -0.017247...  ,
#                                                                  name  \
#  id
#  GGg_emIzQQioLGzsOCS83w  Update API documentation for Teams endpoints
#
#                                                                  embedding
#  id
#  GGg_emIzQQioLGzsOCS83w  [-0.014878921, -0.0015856263, 0.005333072, -0....  ,
#                                                         name  \
#  id
#  c5dddd93-3aa1-495e-b906-111cdaf9b672  Bump teloxide to 0.14
#
#                                                                                embedding
#  id
#  c5dddd93-3aa1-495e-b906-111cdaf9b672  [-0.015975537, -0.028989477, -0.015633814, 0.0...  ,
#                                                                                name  \
#  id
#  abe7198b-5a9c-4d9c-9481-553443bbc976  Export backend logs to gcp or somewhere else
#
#                                                                                embedding
#  id
#  abe7198b-5a9c-4d9c-9481-553443bbc976  [-0.02585356, 0.015935807, 0.115450345, -0.060...  ,
#                                                                                     name  \
#  id
#  c6c22dc4-4cae-4ba9-9a62-2d3954da4289  Add a command to organize tasks in the current...
#
#                                                                                embedding
#  id
#  c6c22dc4-4cae-4ba9-9a62-2d3954da4289  [0.0043522664, 0.01238544, -0.003978967, 0.006...  ,
#                                                                    name  \
#  id
#  p3Vyj_YbQ6ip_XNhbUFpQw  Avoid spawning a background task in GH webhook
#
#                                                                  embedding
#  id
#  p3Vyj_YbQ6ip_XNhbUFpQw  [-0.0049483916, 0.009747226, 0.041225757, -0.0...  ,
#                                                                                     name  \
#  id
#  11d8ee95-973c-4dd6-8dc4-f46adec08e61  Modifying rust code triggers the dependencies ...
#
#                                                                                embedding
#  id
#  11d8ee95-973c-4dd6-8dc4-f46adec08e61  [-0.029199416, 0.026625995, 0.04349337, -0.005...  ,
#                                                                                 name  \
#  id
#  9d405289-0ce8-4fcb-b36d-8aa51bce2fe8  Fix shortcut throwing error for unmapped keys
#
#                                                                                embedding
#  id
#  9d405289-0ce8-4fcb-b36d-8aa51bce2fe8  [0.009622214, 0.030495875, 0.059209343, -0.009...  ,
#                                                                                     name  \
#  id
#  59264388-0427-4dca-8815-df40cd7ae294  Reduce tooltip complexity to make them less an...
#
#                                                                                embedding
#  id
#  59264388-0427-4dca-8815-df40cd7ae294  [-0.0136820255, -0.0013606054, -0.025292063, 0...  ,
#                                                                      name  \
#  id
#  1651b217-b3b3-4fd6-87dc-1c5126c8ae04  Add action / context menu to tasks
#
#                                                                                embedding
#  id
#  1651b217-b3b3-4fd6-87dc-1c5126c8ae04  [-0.07713757, 0.027601141, 0.014881407, -0.018...  ,
#                                                         name  \
#  id
#  9VQI7vStSiKOmD3YFS242Q  initial commit and prop declaration
#
#                                                                  embedding
#  id
#  9VQI7vStSiKOmD3YFS242Q  [0.02756221, 0.046428166, 0.036056224, -0.0141...  ,
#                                                                    name  \
#  id
#  bf0b3290-a46c-43c6-a797-564dcd4c9aac  Rewrite conflicting task numbers
#
#                                                                                embedding
#  id
#  bf0b3290-a46c-43c6-a797-564dcd4c9aac  [-0.007237533, -0.016826717, 0.03949604, -0.05...  ,
#  ...]

# %%
tasks.items()
# Out:
# dict_items([('5da056ad-bc67-42be-9488-e5e2eb93f71c', {'id': '5da056ad-bc67-42be-9488-e5e2eb93f71c', 'num': '470', 'name': 'Update README with once a day / after every pull instructions', 'desc': None, 'children': [], 'assignee': None, 'reporter': None, 'status': 'Done', 'statusTime': 1740170127002, 'url': 'https://github.com/kosolabs/koso/pull/748', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': True}), ('c7ac6432-16f6-45a0-bf8d-11701c3c312f', {'id': 'c7ac6432-16f6-45a0-bf8d-11701c3c312f', 'num': '203', 'name': 'Configure CI', 'desc': None, 'children': [], 'assignee': 'leonhard.kyle@gmail.com', 'reporter': 'leonhard.kyle@gmail.com', 'status': 'Done', 'statusTime': 1727494670266, 'url': None, 'kind': None, 'estimate': None, 'deadline': None, 'archived': None}), ('ZR-1iPe6SWaYYEFbEtKnrg', {'id': 'ZR-1iPe6SWaYYEFbEtKnrg', 'num': '1128', 'name': 'Update dependency svelte to v4.2.19 [SECURITY] - autoclosed', 'desc': None, 'children': [], 'assignee': None, 'reporter': None, 'status': 'Done', 'statusTime': 1753222985807, 'url': 'https://github.com/kosolabs/cipherly/pull/56', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': None}), ('74b0c122-e13b-4718-89d6-7b34c9113ede', {'id': '74b0c122-e13b-4718-89d6-7b34c9113ede', 'num': '1008', 'name': 'Add support for archiving tasks', 'desc': '- Remove the feature for showing / hiding done tasks\n- Replace with ability to show / hide archived tasks\n- Managed tasks should be archiveable as well', 'children': ['c86c5cd4-8955-4fd7-9ccd-09387479387a'], 'assignee': 'leonhard.kyle@gmail.com', 'reporter': 'shadanan@gmail.com', 'status': 'In Progress', 'statusTime': 1749668508413, 'url': None, 'kind': None, 'estimate': 3, 'deadline': None, 'archived': True}), ('P526aJThQA2RNN9oPof7Sw', {'id': 'P526aJThQA2RNN9oPof7Sw', 'num': '1073', 'name': 'Fixup seats verbiage', 'desc': None, 'children': [], 'assignee': 'leonhard.kyle@gmail.com', 'reporter': 'leonhard.kyle@gmail.com', 'status': 'Done', 'statusTime': 1750979008608, 'url': 'https://github.com/kosolabs/koso/pull/1215', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': None}), ('doO8ZK7iSEmduTNDKsn-qA', {'id': 'doO8ZK7iSEmduTNDKsn-qA', 'num': '1116', 'name': 'Add more logging when processing anthropic requests', 'desc': None, 'children': [], 'assignee': 'shadanan@gmail.com', 'reporter': 'shadanan@gmail.com', 'status': 'Done', 'statusTime': 1752597240345, 'url': 'https://github.com/kosolabs/koso/pull/1254', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': None}), ('S6QEkvq5Q-ifbdzHOsgp9w', {'id': 'S6QEkvq5Q-ifbdzHOsgp9w', 'num': '1051', 'name': 'Update dependabot.yml', 'desc': None, 'children': [], 'assignee': 'leonhard.kyle@gmail.com', 'reporter': 'leonhard.kyle@gmail.com', 'status': 'Done', 'statusTime': 1750166937857, 'url': 'https://github.com/kosolabs/koso/pull/1198', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': True}), ('be0f71db-ef88-499c-af80-63c2914a6d01', {'id': 'be0f71db-ef88-499c-af80-63c2914a6d01', 'num': '737', 'name': 'Refactor LinkPanel and TaskStatus to take Task instead of Node', 'desc': None, 'children': [], 'assignee': None, 'reporter': None, 'status': 'Done', 'statusTime': 1744150582793, 'url': 'https://github.com/kosolabs/koso/pull/975', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': True}), ('b3c15ca9-9b86-489c-94a0-da2156ac80ee', {'id': 'b3c15ca9-9b86-489c-94a0-da2156ac80ee', 'num': '830', 'name': 'Open the doors', 'desc': None, 'children': [], 'assignee': None, 'reporter': None, 'status': 'Done', 'statusTime': 1746837801481, 'url': 'https://github.com/kosolabs/koso/pull/1053', 'kind': 'github_pr', 'estimate': None, 'deadline': None, 'archived': True}), ('799abfcd-f39a-4440-833e-7a218d7cd120', {'id': '799abfcd-f39a-4440-833e-7a218d7cd120', 'num': '17', 'name': 'Navbar Improvements', 'desc': None, 'children': ['423a28b8-74ad-4807-80b2-d7dc9ac7ad31', '9b86a483-68e7-4ba8-80c4-9a137d6287a0', 'b488ae9e-60dc-48f ...

# %%
for _, task in tasks.items(): 
    print(task['id'])
# Out:
# 5da056ad-bc67-42be-9488-e5e2eb93f71c
# c7ac6432-16f6-45a0-bf8d-11701c3c312f
# ZR-1iPe6SWaYYEFbEtKnrg
# 74b0c122-e13b-4718-89d6-7b34c9113ede
# P526aJThQA2RNN9oPof7Sw
# doO8ZK7iSEmduTNDKsn-qA
# S6QEkvq5Q-ifbdzHOsgp9w
# be0f71db-ef88-499c-af80-63c2914a6d01
# b3c15ca9-9b86-489c-94a0-da2156ac80ee
# 799abfcd-f39a-4440-833e-7a218d7cd120
# c4830a3c-3909-4807-a6a8-fb46753ec3e0
# 23bb1e72-127b-47e4-9822-59f5731df7b4
# 17912f5c-78e6-4cc2-98d4-129c7fafd15f
# f4f98180-d216-4889-aa4c-ba1c4bf6802d
# f67714fc-8763-4af7-8887-7b0006802295
# 80d3014e-607e-4379-8a37-6c77e44c405b
# 2e7aa496-78d1-4df5-8fcd-31de97ae2a78
# ada31236-ca88-4cdf-8c48-64f7d8f5bc2b
# 7e353788-7924-425f-8d61-2268a0413ec4
# fbadb5ff-f176-4b62-bd8f-1a051b7a1e1a
# f52852ce-b556-47ab-8e24-0f3a5dc61360
# 62666e73-36bb-498c-bcbb-59d151bc4fc8
# 5e6bffc9-b964-4cc0-8dba-af32bac279b6
# 4071b81a-b9f2-4802-b288-09112f44d195
# fc1c98d5-dbd0-4303-9074-b169b231d282
# 22eab22d-68f6-4936-a1cb-77916323c21f
# 5021555b-1b8f-4962-817c-8a2c9b780db1
# ee7f3539-8e7f-4854-ad29-d5b0fe313f43
